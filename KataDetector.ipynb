# %%
# ==============================================
#  Heian Shodan - Enhanced Video Kata Detection with Fixed Time Perception and Key Points Preview
# ==============================================

import cv2
import mediapipe as mp
import numpy as np
import json
import time
import csv
import os

# ==============================================
#  Configuration
INPUT_VIDEO = 'vid.mp4'
OUTPUT_VIDEO = 'output_detected_simple.mp4'
OUTPUT_CSV = 'match_stats_simple.csv'
SIMILARITY_THRESHOLD = 0.55  # Slightly lower due to stricter hybrid matching
STEP_TIMEOUT_SECONDS = 3
START_DELAY_SECONDS = 1
MIN_HOLD_TIME = 0.01 # Minimum time to hold pose

# HYBRID SIMILARITY PARAMETERS
DISTANCE_THRESHOLD = 3.0  # Max allowed average distance between key joints
COSINE_WEIGHT = 0.6       # Weight for angle-based similarity (0-1)
DISTANCE_WEIGHT = 0.4     # Weight for position-based similarity (0-1)

# ==============================================
#  Load reference poses with proper JSON handling
print(" Loading reference poses...")
try:
    with open('heian_shodan_reference.json') as f:
        reference_file_data = json.load(f)
    
    # Handle nested JSON structure
    if isinstance(reference_file_data, dict) and "steps" in reference_file_data:
        reference_data = reference_file_data["steps"]
        print(f" Loaded {len(reference_data)} steps from nested JSON structure")
    else:
        reference_data = reference_file_data
        print(f" Loaded {len(reference_data)} steps from direct array")
        
except FileNotFoundError:
    print(" Error: heian_shodan_reference.json not found!")
    exit()
except json.JSONDecodeError as e:
    print(f" Error: Invalid JSON format - {e}")
    exit()

kata_steps = [
    "Ichi: Left Lower Block",
    "Ni: Right Lunge Punch", 
    "San: Turn & Right Lower Block",
    "Shi: Right Hammerfist Strike",
    "Go: Left Lunge Punch",
    "Roku: Turn & Left Lower Block",
    "Shichi: Right Upper Block",
    "Hachi: Left Upper Block",
    "Ku: Right Upper Block (Kiai)",
    "Ju: Turn & Left Down Block",
    "Ju Ichi: Right Lunge Punch",
    "Ju Ni: Turn & Right Down Block",
    "Ju San: Left Lunge Punch",
    "Ju Shi: Turn & Left Lower Block",
    "Ju Go: Right Lunge Punch",
    "Ju Roku: Left Lunge Punch",
    "Ju Shichi: Right Lunge Punch (2nd Kiai)",
    "Ju Hachi: Left Knife Hand Block"
]

# ==============================================
#  Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=False, model_complexity=1, min_detection_confidence=0.5)
drawing = mp.solutions.drawing_utils

# ==============================================
#  Helper: Normalize landmarks (improved version)
def normalize_landmarks(landmarks):
    """
    Normalize landmarks relative to hip center and scale by torso height
    This gives more consistent, readable values
    """
    # Get key reference points
    left_hip = landmarks[mp_pose.PoseLandmark.LEFT_HIP.value]
    right_hip = landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value]
    left_shoulder = landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value]
    right_shoulder = landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value]
    
    # Calculate center points
    hip_center_x = (left_hip.x + right_hip.x) / 2
    hip_center_y = (left_hip.y + right_hip.y) / 2
    shoulder_center_y = (left_shoulder.y + right_shoulder.y) / 2
    
    # Calculate torso height for scaling
    torso_height = abs(shoulder_center_y - hip_center_y)
    if torso_height < 0.01:  # Prevent division by zero
        torso_height = 0.1
    
    # Normalize all landmarks
    normalized = []
    for lm in landmarks:
        normalized.append([
            round((lm.x - hip_center_x) / torso_height, 3),
            round((lm.y - hip_center_y) / torso_height, 3),
            round(lm.z / torso_height, 3)
        ])
    
    return np.array(normalized).flatten()

# ==============================================
#  Helper: Extract key points preview from normalized pose
def get_key_points_preview(normalized_pose):
    """
    Extract key body points from normalized pose for debugging display
    Returns formatted string with key joint positions
    """
    if normalized_pose is None:
        return " No pose data available"
    
    # Reshape to 33 joints x 3 coordinates
    try:
        pose_3d = np.reshape(normalized_pose, (33, 3))
        
        # Extract key points (using MediaPipe landmark indices)
        left_wrist = pose_3d[mp_pose.PoseLandmark.LEFT_WRIST.value][:2]  # x, y only
        right_wrist = pose_3d[mp_pose.PoseLandmark.RIGHT_WRIST.value][:2]
        left_knee = pose_3d[mp_pose.PoseLandmark.LEFT_KNEE.value][:2]
        right_knee = pose_3d[mp_pose.PoseLandmark.RIGHT_KNEE.value][:2]
        left_elbow = pose_3d[mp_pose.PoseLandmark.LEFT_ELBOW.value][:2]
        right_elbow = pose_3d[mp_pose.PoseLandmark.RIGHT_ELBOW.value][:2]
        
        preview = f"""    Key points preview:
      Left wrist:  ({left_wrist[0]:.2f}, {left_wrist[1]:.2f})
      Right wrist: ({right_wrist[0]:.2f}, {right_wrist[1]:.2f})
      Left elbow:  ({left_elbow[0]:.2f}, {left_elbow[1]:.2f})
      Right elbow: ({right_elbow[0]:.2f}, {right_elbow[1]:.2f})
      Left knee:   ({left_knee[0]:.2f}, {left_knee[1]:.2f})
      Right knee:  ({right_knee[0]:.2f}, {right_knee[1]:.2f})"""
        
        return preview
        
    except Exception as e:
        return f" Error extracting key points: {e}"

# ==============================================
#  Helper: Compare user pose vs reference pose with detailed analysis
def compare_poses_detailed(user_pose, reference_pose, step_name="Unknown"):
    """
    Compare user pose vs reference pose and show detailed side-by-side analysis
    Returns formatted comparison string with differences
    """
    if user_pose is None or reference_pose is None:
        return " Cannot compare - missing pose data"
    
    try:
        user_3d = np.reshape(user_pose, (33, 3))
        ref_3d = np.reshape(reference_pose, (33, 3))
        
        # Extract key points for both poses
        joints = {
            'Left wrist': mp_pose.PoseLandmark.LEFT_WRIST.value,
            'Right wrist': mp_pose.PoseLandmark.RIGHT_WRIST.value,
            'Left elbow': mp_pose.PoseLandmark.LEFT_ELBOW.value,
            'Right elbow': mp_pose.PoseLandmark.RIGHT_ELBOW.value,
            'Left knee': mp_pose.PoseLandmark.LEFT_KNEE.value,
            'Right knee': mp_pose.PoseLandmark.RIGHT_KNEE.value
        }
        
        comparison = f"""    POSE COMPARISON for '{step_name}':
   {'='*60}
   {'Joint':<12} {'User Pose':<18} {'Reference':<18} {'Difference':<12}
   {'-'*60}"""
        
        total_difference = 0
        joint_count = 0
        
        for joint_name, joint_idx in joints.items():
            user_point = user_3d[joint_idx][:2]  # x, y only
            ref_point = ref_3d[joint_idx][:2]
            
            # Calculate euclidean distance difference
            diff_x = user_point[0] - ref_point[0]
            diff_y = user_point[1] - ref_point[1]
            euclidean_diff = np.sqrt(diff_x**2 + diff_y**2)
            
            total_difference += euclidean_diff
            joint_count += 1
            
            # Format the comparison line
            user_str = f"({user_point[0]:.2f}, {user_point[1]:.2f})"
            ref_str = f"({ref_point[0]:.2f}, {ref_point[1]:.2f})"
            diff_str = f"{euclidean_diff:.3f}"
            
            # Add color coding based on difference magnitude
            if euclidean_diff < 2.0:
                status = "✅"
            elif euclidean_diff < 5.0:
                status = "⚠️"
            else:
                status = "❌"
            
            comparison += f"\n   {joint_name:<12} {user_str:<18} {ref_str:<18} {diff_str:<8} {status}"
        
        # Add summary statistics
        avg_difference = total_difference / joint_count if joint_count > 0 else 0
        comparison += f"\n   {'-'*60}"
        comparison += f"\n   Average difference: {avg_difference:.3f}"
        
        if avg_difference < 2.0:
            comparison += " ✅ EXCELLENT MATCH!"
        elif avg_difference < 3.5:
            comparison += " ⚠️  GOOD MATCH"
        elif avg_difference < 6.0:
            comparison += " ⚠️  FAIR MATCH - Minor adjustments needed"
        else:
            comparison += " ❌ POOR MATCH - Significant adjustments needed"
            
        return comparison
        
    except Exception as e:
        return f"❌ Error comparing poses: {e}"

# ==============================================
#  Helper: Extract reference pose data
def extract_reference_pose(step_data):
    """
    Extract reference pose from the JSON data structure
    """
    if "normalized_landmarks" in step_data:
        landmarks = step_data["normalized_landmarks"]
    elif "landmarks_2d" in step_data:
        landmarks = step_data["landmarks_2d"]
    else:
        print(f" Warning: No landmarks found in step data")
        return None
    
    # Convert to the same format as normalized_landmarks function
    pose_array = []
    for lm in landmarks:
        if isinstance(lm, dict):
            pose_array.append([lm['x'], lm['y'], lm['z']])
        else:
            # Handle different data structures
            pose_array.append([lm[0], lm[1], lm[2]])
    
    return np.array(pose_array).flatten()

# ==============================================
#  Helper: HYBRID Pose Similarity - Combines Cosine Similarity + Distance Constraint
def pose_similarity(pose1, pose2, distance_threshold=3.0, cos_weight=0.6, dist_weight=0.4):
    """
    HYBRID pose similarity that combines:
    1. Cosine similarity (for angle/relative positioning) 
    2. Distance constraint (for absolute positioning)
    
    This prevents false positives where poses have similar angles but different positions.
    
    Args:
        pose1, pose2: Normalized pose arrays
        distance_threshold: Max allowed average distance between key joints
        cos_weight: Weight for cosine similarity component (0-1)
        dist_weight: Weight for distance component (0-1)
    """
    if pose1 is None or pose2 is None:
        return 0.0
    
    p1 = np.reshape(pose1, (33, 3))  # 33 joints, each with (x,y,z)
    p2 = np.reshape(pose2, (33, 3))
    
    # ==============================================
    # PART 1: COSINE SIMILARITY (Angle-based)
    # ==============================================
    joint_weights = np.ones(33)  # Default weight of 1.0 for all joints
    
    # ARM AND WRIST JOINTS - Give them higher importance
    arm_wrist_indices = [
        mp_pose.PoseLandmark.LEFT_SHOULDER.value,    # 11
        mp_pose.PoseLandmark.RIGHT_SHOULDER.value,   # 12  
        mp_pose.PoseLandmark.LEFT_ELBOW.value,       # 13
        mp_pose.PoseLandmark.RIGHT_ELBOW.value,      # 14
        mp_pose.PoseLandmark.LEFT_WRIST.value,       # 15 - CRITICAL for arm position
        mp_pose.PoseLandmark.RIGHT_WRIST.value,      # 16 - CRITICAL for arm position
        mp_pose.PoseLandmark.LEFT_PINKY.value,       # 17
        mp_pose.PoseLandmark.RIGHT_PINKY.value,      # 18
        mp_pose.PoseLandmark.LEFT_INDEX.value,       # 19
        mp_pose.PoseLandmark.RIGHT_INDEX.value,      # 20
        mp_pose.PoseLandmark.LEFT_THUMB.value,       # 21
        mp_pose.PoseLandmark.RIGHT_THUMB.value,      # 22
    ]
    
    # Apply higher weights to arm/wrist joints
    ARM_WEIGHT_MULTIPLIER = 3.0
    WRIST_WEIGHT_MULTIPLIER = 4.0
    
    for idx in arm_wrist_indices:
        if idx in [15, 16]:  # LEFT_WRIST, RIGHT_WRIST - most critical
            joint_weights[idx] = WRIST_WEIGHT_MULTIPLIER
        else:  # Other arm joints
            joint_weights[idx] = ARM_WEIGHT_MULTIPLIER
    
    # Calculate weighted cosine similarity across all joints
    cos_similarities = []
    weights = []
    
    for i in range(33):
        joint1 = p1[i]  # 3D vector for joint i
        joint2 = p2[i]  # 3D vector for joint i
        
        # Cosine similarity between corresponding joints
        dot = np.dot(joint1, joint2)
        norm1 = np.linalg.norm(joint1)
        norm2 = np.linalg.norm(joint2)
        
        if norm1 > 0 and norm2 > 0:
            joint_similarity = dot / (norm1 * norm2)
            cos_similarities.append(joint_similarity)
            weights.append(joint_weights[i])
        else:
            cos_similarities.append(0.0)
            weights.append(joint_weights[i])
   
    # Calculate WEIGHTED average cosine similarity
    cos_similarities = np.array(cos_similarities)
    weights = np.array(weights)
    
    cosine_similarity_score = np.sum(cos_similarities * weights) / np.sum(weights)
    
    # ==============================================
    # PART 2: DISTANCE CONSTRAINT (Position-based)
    # ==============================================
    # Focus on key joints for distance measurement
    key_joints_for_distance = [
        mp_pose.PoseLandmark.LEFT_WRIST.value,       # 15
        mp_pose.PoseLandmark.RIGHT_WRIST.value,      # 16
        mp_pose.PoseLandmark.LEFT_ELBOW.value,       # 13
        mp_pose.PoseLandmark.RIGHT_ELBOW.value,      # 14
        mp_pose.PoseLandmark.LEFT_KNEE.value,        # 25
        mp_pose.PoseLandmark.RIGHT_KNEE.value,       # 26
    ]
    
    distances = []
    for joint_idx in key_joints_for_distance:
        # Calculate euclidean distance (using only x,y coordinates)
        joint1_2d = p1[joint_idx][:2]
        joint2_2d = p2[joint_idx][:2]
        
        distance = np.sqrt(np.sum((joint1_2d - joint2_2d)**2))
        distances.append(distance)
    
    avg_distance = np.mean(distances)
    max_distance = np.max(distances)
    
    # Convert distance to similarity score (inverse relationship)
    # Good poses should have small distances (high distance similarity)
    # Bad poses should have large distances (low distance similarity)
    distance_similarity = max(0, 1.0 - (avg_distance / distance_threshold))
    
    # CRITICAL: Apply distance penalty for poses that are too far apart
    # If average distance > threshold, severely penalize the overall score
    distance_penalty = 1.0
    if avg_distance > distance_threshold:
        distance_penalty = max(0.1, 1.0 - ((avg_distance - distance_threshold) / distance_threshold))
    
    # ==============================================
    # PART 3: HYBRID COMBINATION
    # ==============================================
    # Combine cosine similarity and distance similarity
    hybrid_score = (cos_weight * cosine_similarity_score + 
                   dist_weight * distance_similarity) * distance_penalty
    
    # Debug info (optional - can be removed for production)
    if avg_distance > distance_threshold * 1.5:  # Only log problematic cases
        print(f"   🔍 HYBRID DEBUG: COS={cosine_similarity_score:.3f}, DIST_SIM={distance_similarity:.3f}, "
              f"AVG_DIST={avg_distance:.2f}, PENALTY={distance_penalty:.3f}, FINAL={hybrid_score:.3f}")
    
    return hybrid_score

# ==============================================
#  Setup video input and output
print(" Setting up video processing...")

if not os.path.exists(INPUT_VIDEO):
    print(f" Error: Video file {INPUT_VIDEO} not found!")
    exit()

cap = cv2.VideoCapture(INPUT_VIDEO)
if not cap.isOpened():
    print(f" Error: Could not open video {INPUT_VIDEO}")
    exit()

fps = cap.get(cv2.CAP_PROP_FPS)
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
delay_frames = int(fps * START_DELAY_SECONDS)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Setup video output
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(OUTPUT_VIDEO, fourcc, fps, (frame_width, frame_height))

print(f" Video: {INPUT_VIDEO} | FPS: {fps} | Total frames: {total_frames}")
print(f" Output video: {OUTPUT_VIDEO}")
print(f" Output CSV: {OUTPUT_CSV}")

# ==============================================
#  Pre-process reference poses
print(" Pre-processing reference poses...")
processed_reference_poses = []

for i, step_data in enumerate(reference_data):
    ref_pose = extract_reference_pose(step_data)
    if ref_pose is not None:
        processed_reference_poses.append(ref_pose)
        step_name = step_data.get('step_name', kata_steps[i] if i < len(kata_steps) else f'Step {i+1}')
        print(f"    Pose detected and normalized")
        print(f"    Step '{step_name}' processed successfully")
        print(get_key_points_preview(ref_pose))
        print()  # Add spacing between steps
    else:
        print(f"    Step {i+1}: Failed to process")
        processed_reference_poses.append(None)

print(f" Successfully processed {sum(1 for p in processed_reference_poses if p is not None)} reference poses")

# ==============================================
# Detection loop with FIXED TIME PERCEPTION AND HOLD TIMER
current_step = 0
frame_idx = 0
step_results = []
consecutive_good_frames = 0
required_good_frames = int(fps * MIN_HOLD_TIME)
best_similarity_this_step = 0.0

# FIXED: Use frame-based timing instead of mixing real-time and video time
step_start_frame = None
pose_match_start_frame = None
step_completed = False  # NEW: Flag to track if step is completed

print(f" Starting HYBRID pose matching with FIXED TIME PERCEPTION")
print(f" Required good frames: {required_good_frames}")
print(f" Similarity threshold: {SIMILARITY_THRESHOLD}")
print(f" Distance threshold: {DISTANCE_THRESHOLD}")
print(f"  Cosine weight: {COSINE_WEIGHT}, Distance weight: {DISTANCE_WEIGHT}")
print(f" Step timeout: {STEP_TIMEOUT_SECONDS}s ({int(fps * STEP_TIMEOUT_SECONDS)} frames)")
print(f" Video FPS: {fps}")
print("-" * 50)

while cap.isOpened() and current_step < len(reference_data):
    ret, frame = cap.read()
    
    if not ret:
        print(" Video ended.")
        break

    # Handle start delay
    if frame_idx < delay_frames:
        remaining_delay = (delay_frames - frame_idx) / fps
        cv2.putText(frame, f"Starting in {remaining_delay:.1f}s...", 
                   (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 0), 2)
        out.write(frame)
        cv2.imshow("Pose Detection", frame)
        if cv2.waitKey(1) == ord('q'):
            break
        frame_idx += 1
        continue

    # Convert frame index to video timestamp
    video_timestamp = frame_idx / fps
    image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = pose.process(image_rgb)

    # Draw pose landmarks
    if results.pose_landmarks:
        drawing.draw_landmarks(frame, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)
    
    # Check if kata is completed
    if current_step >= len(reference_data):
        cv2.putText(frame, " Kata Completed!", (20, 40), 
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        out.write(frame)
        cv2.imshow("Pose Detection", frame)
        if cv2.waitKey(1) == ord('q'):
            break
        frame_idx += 1
        continue

    if results.pose_landmarks:
        # Initialize step timing if needed (FIXED: Use frame-based timing)
        if step_start_frame is None:
            step_start_frame = frame_idx
            consecutive_good_frames = 0
            pose_match_start_frame = None
            best_similarity_this_step = 0.0
            step_completed = False  # Reset completion flag for new step

        # Calculate pose similarity
        user_pose = normalize_landmarks(results.pose_landmarks.landmark)
        ref_pose = processed_reference_poses[current_step]
        
        if ref_pose is not None:
            similarity = pose_similarity(user_pose, ref_pose, 
                                       distance_threshold=DISTANCE_THRESHOLD,
                                       cos_weight=COSINE_WEIGHT, 
                                       dist_weight=DISTANCE_WEIGHT)
            best_similarity_this_step = max(best_similarity_this_step, similarity)
            
            # FIXED: Calculate elapsed time using frame-based approach
            elapsed_frames = frame_idx - step_start_frame
            elapsed_time = elapsed_frames / fps
            
            pose_is_good = similarity > SIMILARITY_THRESHOLD

            # Handle pose matching logic (FIXED: Frame-based timing)
            if pose_is_good:
                consecutive_good_frames += 1
                if pose_match_start_frame is None:
                    pose_match_start_frame = frame_idx
                    print(f" MATCH STARTED at frame {frame_idx} ({video_timestamp:.2f}s)! Step: {current_step+1}, Similarity: {similarity:.4f}")
                    # Show detailed pose comparison when match starts
                    print(f"    Pose detected and normalized")
                    print(f"   Step '{kata_steps[current_step]}' match detected")
                    print(compare_poses_detailed(user_pose, ref_pose, kata_steps[current_step]))
            else:
                consecutive_good_frames = 0
                pose_match_start_frame = None

            # FIXED: Calculate hold time using frames
            hold_frames = (frame_idx - pose_match_start_frame) if pose_match_start_frame else 0
            hold_time = hold_frames / fps

            # FIXED HOLD TIMER LOGIC: Must meet both frame count AND minimum hold time
            pose_held_long_enough = hold_time >= MIN_HOLD_TIME
            enough_consecutive_frames = consecutive_good_frames >= required_good_frames
            
            # Check for step completion - FIXED: Requires BOTH conditions AND not already completed
            if pose_held_long_enough and enough_consecutive_frames and not step_completed:
                step_results.append((current_step, kata_steps[current_step], video_timestamp, similarity, "SUCCESS"))
                print(f" Step {current_step+1} COMPLETED ({kata_steps[current_step]}) - Similarity: {similarity:.3f} at {video_timestamp:.2f}s (held for {hold_time:.2f}s)")
                print(f"    Pose detected and normalized")
                print(f"   Step '{kata_steps[current_step]}' processed successfully")
                print(compare_poses_detailed(user_pose, ref_pose, kata_steps[current_step]))
                print("-" * 80)
                step_completed = True  # Mark as completed to prevent re-triggering
                
                # FIXED: Properly reset ALL state for next step
                current_step += 1
                step_start_frame = None
                consecutive_good_frames = 0
                pose_match_start_frame = None
                best_similarity_this_step = 0.0
                
            elif elapsed_time >= STEP_TIMEOUT_SECONDS and not step_completed:
                step_results.append((current_step, kata_steps[current_step], video_timestamp, best_similarity_this_step, "TIMEOUT"))
                print(f"⏰ TIMEOUT! Moving on from step {current_step+1} ({kata_steps[current_step]}) - Best similarity: {best_similarity_this_step:.3f} at {video_timestamp:.2f}s")
                print(f"   ❌ Step '{kata_steps[current_step]}' timed out")
                if user_pose is not None:
                    print(compare_poses_detailed(user_pose, ref_pose, kata_steps[current_step]))
                print("-" * 80)
                step_completed = True  # Mark as completed to prevent re-triggering
                
                # FIXED: Properly reset ALL state for next step
                current_step += 1
                step_start_frame = None
                consecutive_good_frames = 0
                pose_match_start_frame = None
                best_similarity_this_step = 0.0

            # Enhanced visual feedback with CORRECTED timing display
            step_name = kata_steps[current_step] if current_step < len(kata_steps) else "Completed"
            
            cv2.putText(frame, f"Step {current_step+1}: {step_name}", (20, 40),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
            cv2.putText(frame, f"Similarity: {similarity:.3f} (Best: {best_similarity_this_step:.3f})", (20, 70),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 0), 2)
            
            # FIXED: Better hold time display with completion status
            hold_status = " READY!" if (pose_held_long_enough and enough_consecutive_frames) else f"{hold_time:.1f}s / {MIN_HOLD_TIME:.1f}s"
            color = (0, 255, 0) if (pose_held_long_enough and enough_consecutive_frames) else (255, 0, 255)
            cv2.putText(frame, f"Hold: {hold_status}", (20, 100),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
            
            cv2.putText(frame, f"Frames: {consecutive_good_frames}/{required_good_frames}", (20, 130),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 0), 2)
            cv2.putText(frame, f"Time: {elapsed_time:.1f}s / {STEP_TIMEOUT_SECONDS:.1f}s", (20, 160),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 2)
            cv2.putText(frame, f"Video Time: {video_timestamp:.2f}s", (20, 190),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (128, 128, 128), 2)

            # FIXED: Better success/failure indicator with hold status
            if step_completed:
                cv2.putText(frame, f"🎯 Step Completed!", (20, 220),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
            elif pose_is_good and pose_held_long_enough and enough_consecutive_frames:
                cv2.putText(frame, f"✅ Hold Complete - Moving to next!", (20, 220),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
            elif pose_is_good:
                cv2.putText(frame, f"🟡 Good Pose - Keep Holding!", (20, 220),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
            else:
                cv2.putText(frame, f"⚠️ Adjust Pose", (20, 220),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        else:
            cv2.putText(frame, f"❌ Reference pose {current_step+1} invalid", (20, 40),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    else:
        cv2.putText(frame, " No pose detected.", (20, 40),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        cv2.putText(frame, f"Video Time: {video_timestamp:.2f}s", (20, 70),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (128, 128, 128), 2)

    # Write frame to output video and display
    out.write(frame)
    cv2.imshow("Pose Detection", frame)
    if cv2.waitKey(1) == ord('q'):
        break
    
    frame_idx += 1

# ==============================================
#  Cleanup and save results
cap.release()
out.release()
cv2.destroyAllWindows()
pose.close()

print("\n" + "="*50)
print(" Video processing completed with FIXED TIME PERCEPTION and KEY POINTS PREVIEW.")
print(f" {sum(1 for r in step_results if r[4] == 'SUCCESS')} steps succeeded / {len(reference_data)} total.")

# Save detailed CSV
with open(OUTPUT_CSV, "w", newline='') as f:
    writer = csv.writer(f)
    writer.writerow(["Step Index", "Step Name", "Timestamp (s)", "Best Similarity", "Status"])
    writer.writerows(step_results)

print(f" CSV saved: {OUTPUT_CSV}")
print(f" Video saved: {OUTPUT_VIDEO}")

# ==============================================
# ✅Summary Statistics
if step_results:
    successful_steps = [r for r in step_results if r[4] == "SUCCESS"]
    timeout_steps = [r for r in step_results if r[4] == "TIMEOUT"]
    
    print(f"\n SUMMARY:")
    print(f"   Successful steps: {len(successful_steps)}")
    print(f"   Timeout steps: {len(timeout_steps)}")
    print(f"   Success rate: {len(successful_steps)/len(reference_data)*100:.1f}%")
    
    if successful_steps:
        avg_similarity = np.mean([r[3] for r in successful_steps])
        print(f"   Average similarity (successful): {avg_similarity:.3f}")
        min_similarity = np.min([r[3] for r in successful_steps])
        max_similarity = np.max([r[3] for r in successful_steps])
        print(f"   Similarity range (successful): {min_similarity:.3f} - {max_similarity:.3f}")
    
    if timeout_steps:
        avg_similarity_timeout = np.mean([r[3] for r in timeout_steps])
        print(f"   Average similarity (timeout): {avg_similarity_timeout:.3f}")


print("   • Combines cosine similarity (angles) + distance constraints (positions)")
print("   • Prevents false positives from similar angles but different positions")
print("   • Configurable distance threshold and weight parameters")
print("   • Distance penalty system for poses that are too far apart")
print("   • Enhanced pose comparison showing user vs reference coordinates")
print("   • Side-by-side analysis with difference calculations")
print("   • Color-coded match quality indicators (✅⚠️❌)")
print("   • Euclidean distance measurements for each joint")
print("   • Average difference scoring with match quality assessment")
print(" Robust pose matching system with hybrid similarity implemented!")
# Out:
#  Loading reference poses...
#  Loaded 18 steps from nested JSON structure
#  Setting up video processing...
#  Video: vid.mp4 | FPS: 38.12452687358062 | Total frames: 1343
#  Output video: output_detected_simple.mp4
#  Output CSV: match_stats_simple.csv
#  Pre-processing reference poses...
#     Pose detected and normalized
#     Step 'Ichi' processed successfully
#     Key points preview:
#       Left wrist:  (0.38, 0.81)
#       Right wrist: (1.08, -0.45)
#       Left elbow:  (1.04, 0.54)
#       Right elbow: (1.73, -0.66)
#       Left knee:   (-0.83, 0.58)
#       Right knee:  (-1.35, -0.50)
#
#     Pose detected and normalized
#     Step 'Ni' processed successfully
#     Key points preview:
#       Left wrist:  (7.00, -0.17)
#       Right wrist: (11.88, 7.93)
#       Left elbow:  (7.61, -2.10)
#       Right elbow: (11.32, 5.69)
#       Left knee:   (-7.62, -1.82)
#       Right knee:  (-6.48, 4.64)
#
#     Pose detected and normalized
#     Step 'San' processed successfully
#     Key points preview:
#       Left wrist:  (5.66, 0.93)
#       Right wrist: (1.23, -4.76)
#       Left elbow:  (7.43, 2.05)
#       Right elbow: (4.44, -3.36)
#       Left knee:   (-6.25, 2.58)
#       Right knee:  (-4.49, -3.14)
#
#     Pose detected and normalized
#     Step 'Shi' processed successfully
#     Key points preview:
#       Left wrist:  (8.34, 2.21)
#       Right wrist: (17.50, -10.27)
#       Left elbow:  (12.01, 3.88)
#       Right elbow: (15.08, -7.13)
#       Left knee:   (-11.27, 3.79)
#       Right knee:  (-8.39, -5.52)
#
#     Pose detected and normalized
#     Step 'Go' processed successfully
#     Key points preview:
#       Left wrist:  (18.27, -11.45)
#       Right wrist: (8.58, 2.43)
#       Left elbow:  (17.87, -7.68)
#       Right elbow: (13.26, 4.50)
#       Left knee:   (-10.48, -6.31)
#       Right knee:  (-11.74, 2.80)
#
#     Pose detected and normalized
#     Step 'Roku' processed successfully
#     Key points preview:
#       Left wrist:  (-0.04, 0.36)
#       Right wrist: (0.28, -0.20)
#       Left elbow:  (0.79, 0.30)
#       Right elbow: (0.95, -0.21)
#       Left knee:   (-1.31, 0.20)
#       Right knee:  (-1.11, -0.27)
#
#     Pose detected and normalized
#     Step 'Shichi' processed successfully
#     Key points preview:
#       Left wrist:  (0.88, 0.35)
#       Right wrist: (3.02, 0.26)
#       Left elbow:  (1.22, 0.17)
#       Right elbow: (2.87, -0.17)
#       Left knee:   (-1.25, 0.25)
#       Right knee:  (-1.31, -0.18)
#
#     Pose detected and normalized
#     Step 'Hachi' processed successfully
#     Key points preview:
#       Left wrist:  (3.64, -0.46)
#       Right wrist: (0.41, -0.23)
#       Left elbow:  (3.25, -0.02)
#       Right elbow: (1.33, -0.28)
#       Left knee:   (-1.65, 0.20)
#       Right knee:  (-1.53, -0.40)
#
#     Pose detected and normalized
#     Step 'Ku' processed successfully
#     Key points preview:
#       Left wrist:  (1.39, 0.49)
#       Right wrist: (4.24, 0.27)
#       Left elbow:  (1.51, 0.40)
#       Right elbow: (4.04, -0.31)
#       Left knee:   (-1.52, 0.38)
#       Right knee:  (-1.80, -0.18)
#
#     Pose detected and normalized
#     Step 'Ju' processed successfully
#     Key points preview:
#       Left wrist:  (-0.13, -1.03)
#       Right wrist: (0.93, 0.40)
#       Left elbow:  (0.99, -0.71)
#       Right elbow: (1.73, 0.71)
#       Left knee:   (-1.68, -0.79)
#       Right knee:  (-1.80, 0.39)
#
#     Pose detected and normalized
#     Step 'Ju Ichi' processed successfully
#     Key points preview:
#       Left wrist:  (5.47, -0.39)
#       Right wrist: (11.66, -7.11)
#       Left elbow:  (7.44, 2.00)
#       Right elbow: (11.06, -4.62)
#       Left knee:   (-8.56, 1.75)
#       Right knee:  (-5.68, -3.15)
#
#     Pose detected and normalized
#     Step 'Ju Ni' processed successfully
#     Key points preview:
#       Left wrist:  (5.05, -0.43)
#       Right wrist: (-0.86, 5.57)
#       Left elbow:  (7.62, -2.39)
#       Right elbow: (3.96, 3.90)
#       Left knee:   (-8.06, -2.13)
#       Right knee:  (-8.39, 2.51)
#
#     Pose detected and normalized
#     Step 'Ju San' processed successfully
#     Key points preview:
#       Left wrist:  (10.79, 7.20)
#       Right wrist: (4.70, -0.88)
#       Left elbow:  (10.28, 4.65)
#       Right elbow: (8.09, -2.64)
#       Left knee:   (-6.06, 3.03)
#       Right knee:  (-8.10, -1.99)
#
#     Pose detected and normalized
#     Step 'Ju Shi' processed successfully
#     Key points preview:
#       Left wrist:  (4.46, 0.72)
#       Right wrist: (3.38, 2.91)
#       Left elbow:  (7.41, -0.66)
#       Right elbow: (6.39, 1.94)
#       Left knee:   (-9.82, -1.12)
#       Right knee:  (-11.52, 1.68)
#
#     Pose detected and normalized
#     Step 'Ju Go' processed successfully
#     Key points preview:
#       Left wrist:  (1.21, -0.30)
#       Right wrist: (1.70, -0.02)
#       Left elbow:  (1.31, -0.50)
#       Right elbow: (1.47, 0.27)
#       Left knee:   (-1.77, -0.40)
#       Right knee:  (-1.37, 0.27)
#
#     Pose detected and normalized
#     Step 'Ju Roku' processed successfully
#     Key points preview:
#       Left wrist:  (10.13, -1.50)
#       Right wrist: (6.63, 2.56)
#       Left elbow:  (9.28, -2.66)
#       Right elbow: (7.52, 4.36)
#       Left knee:   (-8.20, -1.95)
#       Right knee:  (-9.97, 2.44)
#
#     Pose detected and normalized
#     Step 'Ju Shichi' processed successfully
#     Key points preview:
#       Left wrist:  (0.95, -0.17)
#       Right wrist: (1.48, 0.09)
#       Left elbow:  (0.89, -0.35)
#       Right elbow: (1.12, 0.27)
#       Left knee:   (-1.21, -0.33)
#       Right knee:  (-1.01, 0.23)
#
#     Pose detected and normalized
#     Step 'Ju Hachi' processed successfully
#     Key points preview:
#       Left wrist:  (1.57, 0.81)
#       Right wrist: (1.08, 0.21)
#       Left elbow:  (1.35, 0.42)
#       Right elbow: (0.82, -0.23)
#       Left knee:   (-1.06, 0.59)
#       Right knee:  (-1.45, -0.28)
#
#  Successfully processed 18 reference poses
#  Starting HYBRID pose matching with FIXED TIME PERCEPTION
#  Required good frames: 0
#  Similarity threshold: 0.55
#  Distance threshold: 3.0
#   Cosine weight: 0.6, Distance weight: 0.4
#  Step timeout: 3s (114 frames)
#  Video FPS: 38.12452687358062
# --------------------------------------------------
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1754516133.698871 1462182 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1754516133.857657 1462350 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1754516133.879698 1462350 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1754516135.496598 1462350 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
#  MATCH STARTED at frame 38 (1.00s)! Step: 1, Similarity: 0.9693
#     Pose detected and normalized
#    Step 'Ichi: Left Lower Block' match detected
#     POSE COMPARISON for 'Ichi: Left Lower Block':
#    ============================================================
#    Joint        User Pose          Reference          Difference
#    ------------------------------------------------------------
#    Left wrist   (0.38, 0.72)       (0.38, 0.81)       0.081    ✅
#    Right wrist  (1.00, -0.44)      (1.08, -0.45)      0.079    ✅
#    Left elbow   (1.06, 0.47)       (1.04, 0.54)       0.074    ✅
#    Right elbow  (1.60, -0.68)      (1.73, -0.66)      0.134    ✅
#    Left knee    (-0.96, 0.56)      (-0.83, 0.58)      0.135    ✅
#    Right knee   (-1.37, -0.45)     (-1.35, -0.50)     0.057    ✅
#    ------------------------------------------------------------
#    Average difference: 0.093 ✅ EXCELLENT MATCH!
#  Step 1 COMPLETED (Ichi: Left Lower Block) - Similarity: 0.775 at 1.02s (held for 0.03s)
#     Pose detected and normalized
#    Step 'Ichi: Left Lower Block' processed successfully
#     POSE COMPARISON for 'Ichi: Left Lower Block':
#    ============================================================
#    Joint        User Pose          Reference          Difference
#    ------------------------------------------------------------
#    Left wrist   (0.40, 0.74)       (0.38, 0.81)       0.063    ✅
#    Right wrist  (1.01, -0.42)      (1.08, -0.45)      0.071    ✅
#    Left elbow   (1.09, 0.50)       (1.04, 0.54)       0.068    ✅
#    Right elbow  (1.64, -0.66)      (1.73, -0.66)      0.093    ✅
#    Left knee    (-0.88, 0.59)      (-0.83, 0.58)      0.057    ✅
#    Right knee   (-1.35, -0.45)     (-1.35, -0.50)     0.060    ✅
#    ------------------------------------------------------------
#    Average difference: 0.069 ✅ EXCELLENT MATCH!
# --------------------------------------------------------------------------------
#    🔍 HYBRID DEBUG: COS=0.678, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.041
#    🔍 HYBRID DEBUG: COS=0.601, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.036
#    🔍 HYBRID DEBUG: COS=0.577, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.035
#    🔍 HYBRID DEBUG: COS=0.586, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.035
#    🔍 HYBRID DEBUG: COS=0.477, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.029
#    🔍 HYBRID DEBUG: COS=0.435, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.026
#    🔍 HYBRID DEBUG: COS=0.401, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.024
#    🔍 HYBRID DEBUG: COS=0.346, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.021
#    🔍 HYBRID DEBUG: COS=0.337, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.020
#    🔍 HYBRID DEBUG: COS=0.346, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.021
#    🔍 HYBRID DEBUG: COS=0.349, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.021
#    🔍 HYBRID DEBUG: COS=0.347, DIST_SIM=0.000, AVG_DIST=8.88, PENALTY=0.100, FINAL=0.021
#    🔍 HYBRID DEBUG: COS=0.344, DIST_SIM=0.000, AVG_DIST=8.88, PENALTY=0.100, FINAL=0.021
#    🔍 HYBRID DEBUG: COS=0.330, DIST_SIM=0.000, AVG_DIST=8.88, PENALTY=0.100, FINAL=0.020
#    🔍 HYBRID DEBUG: COS=0.327, DIST_SIM=0.000, AVG_DIST=8.87, PENALTY=0.100, FINAL=0.020
#    🔍 HYBRID DEBUG: COS=0.321, DIST_SIM=0.000, AVG_DIST=8.88, PENALTY=0.100, FINAL=0.019
#    🔍 HYBRID DEBUG: COS=0.314, DIST_SIM=0.000, AVG_DIST=8.88, PENALTY=0.100, FINAL=0.019
#    🔍 HYBRID DEBUG: COS=0.321, DIST_SIM=0.000, AVG_DIST=8.88, PENALTY=0.100, FINAL=0.019
#    🔍 HYBRID DEBUG: COS=0.325, DIST_SIM=0.000, AVG_DIST=8.88, PENALTY=0.100, FINAL=0.020
#    🔍 HYBRID DEBUG: COS=0.324, DIST_SIM=0.000, AVG_DIST=8.88, PENALTY=0.100, FINAL=0.019
#    🔍 HYBRID DEBUG: COS=0.323, DIST_SIM=0.000, AVG_DIST=8.88, PENALTY=0.100, FINAL=0.019
#    🔍 HYBRID DEBUG: COS=0.324, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.019
#    🔍 HYBRID DEBUG: COS=0.323, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.019
#    🔍 HYBRID DEBUG: COS=0.353, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.021
#    🔍 HYBRID DEBUG: COS=0.352, DIST_SIM=0.000, AVG_DIST=8.90, PENALTY=0.100, FINAL=0.021
#    🔍 HYBRID DEBUG: COS=0.362, DIST_SIM=0.000, AVG_DIST=8.90, PENALTY=0.100, FINAL=0.022
#    🔍 HYBRID DEBUG: COS=0.366, DIST_SIM=0.000, AVG_DIST=8.90, PENALTY=0.100, FINAL=0.022
#    🔍 HYBRID DEBUG: COS=0.361, DIST_SIM=0.000, AVG_DIST=8.90, PENALTY=0.100, FINAL=0.022
#    🔍 HYBRID DEBUG: COS=0.360, DIST_SIM=0.000, AVG_DIST=8.90, PENALTY=0.100, FINAL=0.022
#    🔍 HYBRID DEBUG: COS=0.353, DIST_SIM=0.000, AVG_DIST=8.90, PENALTY=0.100, FINAL=0.021
#    🔍 HYBRID DEBUG: COS=0.337, DIST_SIM=0.000, AVG_DIST=8.90, PENALTY=0.100, FINAL=0.020
#    🔍 HYBRID DEBUG: COS=0.329, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.020
#    🔍 HYBRID DEBUG: COS=0.326, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.020
#    🔍 HYBRID DEBUG: COS=0.316, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.019
#    🔍 HYBRID DEBUG: COS=0.311, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.019
#    🔍 HYBRID DEBUG: COS=0.315, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.019
#    🔍 HYBRID DEBUG: COS=0.316, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.019
#    🔍 HYBRID DEBUG: COS=0.314, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.019
#    🔍 HYBRID DEBUG: COS=0.314, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.019
#    🔍 HYBRID DEBUG: COS=0.312, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.019
#    🔍 HYBRID DEBUG: COS=0.314, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.019
#    🔍 HYBRID DEBUG: COS=0.325, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.020
#    🔍 HYBRID DEBUG: COS=0.325, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.020
#    🔍 HYBRID DEBUG: COS=0.320, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.019
#    🔍 HYBRID DEBUG: COS=0.317, DIST_SIM=0.000, AVG_DIST=8.89, PENALTY=0.100, FINAL=0.019
#    🔍 HYBRID DEBUG: COS=0.325, DIST_SIM=0.000, AVG_DIST=8.88, PENALTY=0.100, FINAL=0.020
#    🔍 HYBRID DEBUG: COS=0.335, DIST_SIM=0.000, AVG_DIST=8.88, PENALTY=0.100, FINAL=0.020
#    🔍 HYBRID DEBUG: COS=0.479, DIST_SIM=0.000, AVG_DIST=8.88, PENALTY=0.100, FINAL=0.029
#    🔍 HYBRID DEBUG: COS=0.436, DIST_SIM=0.000, AVG_DIST=8.88, PENALTY=0.100, FINAL=0.026
#    🔍 HYBRID DEBUG: COS=0.342, DIST_SIM=0.000, AVG_DIST=8.88, PENALTY=0.100, FINAL=0.021
#    🔍 HYBRID DEBUG: COS=0.346, DIST_SIM=0.000, AVG_DIST=8.88, PENALTY=0.100, FINAL=0.021
#    🔍 HYBRID DEBUG: COS=0.357, DIST_SIM=0.000, AVG_DIST=9.73, PENALTY=0.100, FINAL=0.021
#    🔍 HYBRID DEBUG: COS=0.347, DIST_SIM=0.000, AVG_DIST=9.78, PENALTY=0.100, FINAL=0.021
#    🔍 HYBRID DEBUG: COS=0.350, DIST_SIM=0.000, AVG_DIST=8.63, PENALTY=0.100, FINAL=0.021
#    🔍 HYBRID DEBUG: COS=0.330, DIST_SIM=0.000, AVG_DIST=8.43, PENALTY=0.100, FINAL=0.020
#    🔍 HYBRID DEBUG: COS=0.322, DIST_SIM=0.000, AVG_DIST=7.98, PENALTY=0.100, FINAL=0.019
#    🔍 HYBRID DEBUG: COS=0.315, DIST_SIM=0.000, AVG_DIST=7.90, PENALTY=0.100, FINAL=0.019
#    🔍 HYBRID DEBUG: COS=0.379, DIST_SIM=0.000, AVG_DIST=7.78, PENALTY=0.100, FINAL=0.023
#    🔍 HYBRID DEBUG: COS=0.379, DIST_SIM=0.000, AVG_DIST=7.69, PENALTY=0.100, FINAL=0.023
#    🔍 HYBRID DEBUG: COS=0.440, DIST_SIM=0.000, AVG_DIST=7.55, PENALTY=0.100, FINAL=0.026
#    🔍 HYBRID DEBUG: COS=0.517, DIST_SIM=0.000, AVG_DIST=7.51, PENALTY=0.100, FINAL=0.031
#    🔍 HYBRID DEBUG: COS=0.457, DIST_SIM=0.000, AVG_DIST=7.36, PENALTY=0.100, FINAL=0.027
#    🔍 HYBRID DEBUG: COS=0.457, DIST_SIM=0.000, AVG_DIST=7.34, PENALTY=0.100, FINAL=0.027
#    🔍 HYBRID DEBUG: COS=0.553, DIST_SIM=0.000, AVG_DIST=7.26, PENALTY=0.100, FINAL=0.033
#    🔍 HYBRID DEBUG: COS=0.604, DIST_SIM=0.000, AVG_DIST=7.21, PENALTY=0.100, FINAL=0.036
#    🔍 HYBRID DEBUG: COS=0.705, DIST_SIM=0.000, AVG_DIST=7.03, PENALTY=0.100, FINAL=0.042
#    🔍 HYBRID DEBUG: COS=0.702, DIST_SIM=0.000, AVG_DIST=6.98, PENALTY=0.100, FINAL=0.042
#    🔍 HYBRID DEBUG: COS=0.746, DIST_SIM=0.000, AVG_DIST=6.84, PENALTY=0.100, FINAL=0.045
#    🔍 HYBRID DEBUG: COS=0.752, DIST_SIM=0.000, AVG_DIST=6.79, PENALTY=0.100, FINAL=0.045
#    🔍 HYBRID DEBUG: COS=0.713, DIST_SIM=0.000, AVG_DIST=8.19, PENALTY=0.100, FINAL=0.043
#    🔍 HYBRID DEBUG: COS=0.735, DIST_SIM=0.000, AVG_DIST=7.80, PENALTY=0.100, FINAL=0.044
#    🔍 HYBRID DEBUG: COS=0.699, DIST_SIM=0.000, AVG_DIST=8.53, PENALTY=0.100, FINAL=0.042
#    🔍 HYBRID DEBUG: COS=0.713, DIST_SIM=0.000, AVG_DIST=8.43, PENALTY=0.100, FINAL=0.043
#    🔍 HYBRID DEBUG: COS=0.779, DIST_SIM=0.000, AVG_DIST=8.73, PENALTY=0.100, FINAL=0.047
#    🔍 HYBRID DEBUG: COS=0.792, DIST_SIM=0.000, AVG_DIST=8.74, PENALTY=0.100, FINAL=0.048
#    🔍 HYBRID DEBUG: COS=0.750, DIST_SIM=0.000, AVG_DIST=8.74, PENALTY=0.100, FINAL=0.045
#    🔍 HYBRID DEBUG: COS=0.774, DIST_SIM=0.000, AVG_DIST=8.75, PENALTY=0.100, FINAL=0.046
#    🔍 HYBRID DEBUG: COS=0.792, DIST_SIM=0.000, AVG_DIST=8.72, PENALTY=0.100, FINAL=0.048
#    🔍 HYBRID DEBUG: COS=0.804, DIST_SIM=0.000, AVG_DIST=8.71, PENALTY=0.100, FINAL=0.048
#    🔍 HYBRID DEBUG: COS=0.792, DIST_SIM=0.000, AVG_DIST=8.53, PENALTY=0.100, FINAL=0.048
#    🔍 HYBRID DEBUG: COS=0.792, DIST_SIM=0.000, AVG_DIST=8.49, PENALTY=0.100, FINAL=0.048
#    🔍 HYBRID DEBUG: COS=0.859, DIST_SIM=0.000, AVG_DIST=5.43, PENALTY=0.191, FINAL=0.098
#    🔍 HYBRID DEBUG: COS=0.859, DIST_SIM=0.000, AVG_DIST=5.44, PENALTY=0.188, FINAL=0.097
#    🔍 HYBRID DEBUG: COS=0.938, DIST_SIM=0.000, AVG_DIST=4.85, PENALTY=0.385, FINAL=0.217
#    🔍 HYBRID DEBUG: COS=0.955, DIST_SIM=0.000, AVG_DIST=8.33, PENALTY=0.100, FINAL=0.057
#    🔍 HYBRID DEBUG: COS=0.959, DIST_SIM=0.000, AVG_DIST=8.33, PENALTY=0.100, FINAL=0.058
#    🔍 HYBRID DEBUG: COS=0.972, DIST_SIM=0.000, AVG_DIST=8.25, PENALTY=0.100, FINAL=0.058
#    🔍 HYBRID DEBUG: COS=0.953, DIST_SIM=0.000, AVG_DIST=8.26, PENALTY=0.100, FINAL=0.057
#    🔍 HYBRID DEBUG: COS=0.883, DIST_SIM=0.000, AVG_DIST=4.58, PENALTY=0.472, FINAL=0.250
#  MATCH STARTED at frame 137 (3.59s)! Step: 2, Similarity: 0.6753
#     Pose detected and normalized
#    Step 'Ni: Right Lunge Punch' match detected
#     POSE COMPARISON for 'Ni: Right Lunge Punch':
#    ============================================================
#    Joint        User Pose          Reference          Difference
#    ------------------------------------------------------------
#    Left wrist   (8.10, -0.54)      (7.00, -0.17)      1.158    ✅
#    Right wrist  (15.20, 9.86)      (11.88, 7.93)      3.837    ⚠️
#    Left elbow   (9.03, -2.79)      (7.61, -2.10)      1.572    ✅
#    Right elbow  (14.25, 6.66)      (11.32, 5.69)      3.090    ⚠️
#    Left knee    (-9.16, -1.90)     (-7.62, -1.82)     1.540    ✅
#    Right knee   (-8.35, 5.43)      (-6.48, 4.64)      2.030    ⚠️
#    ------------------------------------------------------------
#    Average difference: 2.205 ⚠️  GOOD MATCH
#  Step 2 COMPLETED (Ni: Right Lunge Punch) - Similarity: 0.773 at 3.62s (held for 0.03s)
#     Pose detected and normalized
#    Step 'Ni: Right Lunge Punch' processed successfully
#     POSE COMPARISON for 'Ni: Right Lunge Punch':
#    ============================================================
#    Joint        User Pose          Reference          Difference
#    ------------------------------------------------------------
#    Left wrist   (7.52, -0.52)      (7.00, -0.17)      0.627    ✅
#    Right wrist  (14.14, 9.23)      (11.88, 7.93)      2.605    ⚠️
#    Left elbow   (8.45, -2.58)      (7.61, -2.10)      0.965    ✅
#    Right elbow  (13.29, 6.30)      (11.32, 5.69)      2.061    ⚠️
#    Left knee    (-8.55, -1.82)     (-7.62, -1.82)     0.923    ✅
#    Right knee   (-7.77, 5.07)      (-6.48, 4.64)      1.366    ✅
#    ------------------------------------------------------------
#    Average difference: 1.425 ✅ EXCELLENT MATCH!
# --------------------------------------------------------------------------------
#    🔍 HYBRID DEBUG: COS=-0.313, DIST_SIM=0.000, AVG_DIST=8.06, PENALTY=0.100, FINAL=-0.019
#    🔍 HYBRID DEBUG: COS=-0.315, DIST_SIM=0.000, AVG_DIST=7.78, PENALTY=0.100, FINAL=-0.019
#    🔍 HYBRID DEBUG: COS=-0.280, DIST_SIM=0.000, AVG_DIST=7.72, PENALTY=0.100, FINAL=-0.017
#    🔍 HYBRID DEBUG: COS=-0.273, DIST_SIM=0.000, AVG_DIST=7.77, PENALTY=0.100, FINAL=-0.016
#    🔍 HYBRID DEBUG: COS=-0.273, DIST_SIM=0.000, AVG_DIST=7.69, PENALTY=0.100, FINAL=-0.016
#    🔍 HYBRID DEBUG: COS=-0.270, DIST_SIM=0.000, AVG_DIST=7.72, PENALTY=0.100, FINAL=-0.016
#    🔍 HYBRID DEBUG: COS=-0.305, DIST_SIM=0.000, AVG_DIST=7.83, PENALTY=0.100, FINAL=-0.018
#    🔍 HYBRID DEBUG: COS=-0.300, DIST_SIM=0.000, AVG_DIST=7.93, PENALTY=0.100, FINAL=-0.018
#    🔍 HYBRID DEBUG: COS=-0.341, DIST_SIM=0.000, AVG_DIST=7.97, PENALTY=0.100, FINAL=-0.020
#    🔍 HYBRID DEBUG: COS=-0.334, DIST_SIM=0.000, AVG_DIST=7.97, PENALTY=0.100, FINAL=-0.020
#    🔍 HYBRID DEBUG: COS=-0.321, DIST_SIM=0.000, AVG_DIST=8.07, PENALTY=0.100, FINAL=-0.019
#    🔍 HYBRID DEBUG: COS=-0.300, DIST_SIM=0.000, AVG_DIST=8.16, PENALTY=0.100, FINAL=-0.018
#    🔍 HYBRID DEBUG: COS=-0.310, DIST_SIM=0.000, AVG_DIST=8.04, PENALTY=0.100, FINAL=-0.019
#    🔍 HYBRID DEBUG: COS=-0.320, DIST_SIM=0.000, AVG_DIST=7.91, PENALTY=0.100, FINAL=-0.019
#    🔍 HYBRID DEBUG: COS=-0.324, DIST_SIM=0.000, AVG_DIST=7.91, PENALTY=0.100, FINAL=-0.019
#    🔍 HYBRID DEBUG: COS=-0.326, DIST_SIM=0.000, AVG_DIST=7.92, PENALTY=0.100, FINAL=-0.020
#    🔍 HYBRID DEBUG: COS=-0.338, DIST_SIM=0.000, AVG_DIST=7.86, PENALTY=0.100, FINAL=-0.020
#    🔍 HYBRID DEBUG: COS=-0.342, DIST_SIM=0.000, AVG_DIST=7.85, PENALTY=0.100, FINAL=-0.021
#    🔍 HYBRID DEBUG: COS=-0.357, DIST_SIM=0.000, AVG_DIST=7.88, PENALTY=0.100, FINAL=-0.021
#    🔍 HYBRID DEBUG: COS=-0.360, DIST_SIM=0.000, AVG_DIST=7.90, PENALTY=0.100, FINAL=-0.022
#    🔍 HYBRID DEBUG: COS=-0.361, DIST_SIM=0.000, AVG_DIST=7.92, PENALTY=0.100, FINAL=-0.022
#    🔍 HYBRID DEBUG: COS=-0.355, DIST_SIM=0.000, AVG_DIST=7.94, PENALTY=0.100, FINAL=-0.021
#    🔍 HYBRID DEBUG: COS=-0.360, DIST_SIM=0.000, AVG_DIST=7.94, PENALTY=0.100, FINAL=-0.022
#    🔍 HYBRID DEBUG: COS=-0.355, DIST_SIM=0.000, AVG_DIST=7.92, PENALTY=0.100, FINAL=-0.021
#    🔍 HYBRID DEBUG: COS=-0.344, DIST_SIM=0.000, AVG_DIST=7.91, PENALTY=0.100, FINAL=-0.021
#    🔍 HYBRID DEBUG: COS=-0.338, DIST_SIM=0.000, AVG_DIST=7.91, PENALTY=0.100, FINAL=-0.020
#    🔍 HYBRID DEBUG: COS=-0.330, DIST_SIM=0.000, AVG_DIST=7.91, PENALTY=0.100, FINAL=-0.020
#    🔍 HYBRID DEBUG: COS=-0.329, DIST_SIM=0.000, AVG_DIST=7.90, PENALTY=0.100, FINAL=-0.020
#    🔍 HYBRID DEBUG: COS=-0.329, DIST_SIM=0.000, AVG_DIST=7.89, PENALTY=0.100, FINAL=-0.020
#    🔍 HYBRID DEBUG: COS=-0.327, DIST_SIM=0.000, AVG_DIST=7.88, PENALTY=0.100, FINAL=-0.020
#    🔍 HYBRID DEBUG: COS=-0.275, DIST_SIM=0.000, AVG_DIST=7.90, PENALTY=0.100, FINAL=-0.016
#    🔍 HYBRID DEBUG: COS=-0.269, DIST_SIM=0.000, AVG_DIST=7.90, PENALTY=0.100, FINAL=-0.016
#    🔍 HYBRID DEBUG: COS=-0.260, DIST_SIM=0.000, AVG_DIST=7.83, PENALTY=0.100, FINAL=-0.016
#    🔍 HYBRID DEBUG: COS=-0.255, DIST_SIM=0.000, AVG_DIST=7.79, PENALTY=0.100, FINAL=-0.015
#    🔍 HYBRID DEBUG: COS=-0.268, DIST_SIM=0.000, AVG_DIST=7.70, PENALTY=0.100, FINAL=-0.016
#    🔍 HYBRID DEBUG: COS=-0.272, DIST_SIM=0.000, AVG_DIST=7.64, PENALTY=0.100, FINAL=-0.016
#    🔍 HYBRID DEBUG: COS=-0.276, DIST_SIM=0.000, AVG_DIST=7.52, PENALTY=0.100, FINAL=-0.017
#    🔍 HYBRID DEBUG: COS=-0.280, DIST_SIM=0.000, AVG_DIST=7.44, PENALTY=0.100, FINAL=-0.017
#    🔍 HYBRID DEBUG: COS=-0.290, DIST_SIM=0.000, AVG_DIST=7.65, PENALTY=0.100, FINAL=-0.017
#    🔍 HYBRID DEBUG: COS=-0.296, DIST_SIM=0.000, AVG_DIST=7.71, PENALTY=0.100, FINAL=-0.018
#    🔍 HYBRID DEBUG: COS=-0.301, DIST_SIM=0.000, AVG_DIST=8.02, PENALTY=0.100, FINAL=-0.018
#    🔍 HYBRID DEBUG: COS=-0.300, DIST_SIM=0.000, AVG_DIST=8.09, PENALTY=0.100, FINAL=-0.018
#    🔍 HYBRID DEBUG: COS=-0.275, DIST_SIM=0.000, AVG_DIST=7.90, PENALTY=0.100, FINAL=-0.016
#    🔍 HYBRID DEBUG: COS=-0.283, DIST_SIM=0.000, AVG_DIST=7.74, PENALTY=0.100, FINAL=-0.017
#    🔍 HYBRID DEBUG: COS=-0.251, DIST_SIM=0.000, AVG_DIST=8.50, PENALTY=0.100, FINAL=-0.015
#    🔍 HYBRID DEBUG: COS=-0.295, DIST_SIM=0.000, AVG_DIST=8.43, PENALTY=0.100, FINAL=-0.018
#    🔍 HYBRID DEBUG: COS=-0.271, DIST_SIM=0.000, AVG_DIST=10.45, PENALTY=0.100, FINAL=-0.016
#    🔍 HYBRID DEBUG: COS=-0.228, DIST_SIM=0.000, AVG_DIST=9.52, PENALTY=0.100, FINAL=-0.014
#    🔍 HYBRID DEBUG: COS=-0.432, DIST_SIM=0.000, AVG_DIST=5.51, PENALTY=0.164, FINAL=-0.042
#    🔍 HYBRID DEBUG: COS=-0.374, DIST_SIM=0.000, AVG_DIST=5.49, PENALTY=0.169, FINAL=-0.038
#    🔍 HYBRID DEBUG: COS=-0.414, DIST_SIM=0.000, AVG_DIST=5.53, PENALTY=0.157, FINAL=-0.039
#    🔍 HYBRID DEBUG: COS=-0.419, DIST_SIM=0.000, AVG_DIST=5.55, PENALTY=0.150, FINAL=-0.038
#    🔍 HYBRID DEBUG: COS=-0.165, DIST_SIM=0.000, AVG_DIST=5.44, PENALTY=0.188, FINAL=-0.019
#    🔍 HYBRID DEBUG: COS=-0.161, DIST_SIM=0.000, AVG_DIST=5.43, PENALTY=0.191, FINAL=-0.018
#    🔍 HYBRID DEBUG: COS=-0.046, DIST_SIM=0.000, AVG_DIST=5.16, PENALTY=0.279, FINAL=-0.008
#    🔍 HYBRID DEBUG: COS=-0.080, DIST_SIM=0.000, AVG_DIST=5.18, PENALTY=0.275, FINAL=-0.013
#    🔍 HYBRID DEBUG: COS=-0.043, DIST_SIM=0.000, AVG_DIST=5.02, PENALTY=0.328, FINAL=-0.009
#    🔍 HYBRID DEBUG: COS=-0.018, DIST_SIM=0.000, AVG_DIST=4.99, PENALTY=0.337, FINAL=-0.004
#    🔍 HYBRID DEBUG: COS=-0.019, DIST_SIM=0.000, AVG_DIST=4.97, PENALTY=0.343, FINAL=-0.004
#    🔍 HYBRID DEBUG: COS=-0.021, DIST_SIM=0.000, AVG_DIST=8.22, PENALTY=0.100, FINAL=-0.001
#    🔍 HYBRID DEBUG: COS=0.060, DIST_SIM=0.000, AVG_DIST=4.96, PENALTY=0.348, FINAL=0.013
#    🔍 HYBRID DEBUG: COS=0.058, DIST_SIM=0.000, AVG_DIST=4.96, PENALTY=0.345, FINAL=0.012
#    🔍 HYBRID DEBUG: COS=0.427, DIST_SIM=0.000, AVG_DIST=4.99, PENALTY=0.338, FINAL=0.087
#    🔍 HYBRID DEBUG: COS=0.354, DIST_SIM=0.000, AVG_DIST=5.00, PENALTY=0.334, FINAL=0.071
#    🔍 HYBRID DEBUG: COS=0.508, DIST_SIM=0.000, AVG_DIST=5.04, PENALTY=0.319, FINAL=0.097
#    🔍 HYBRID DEBUG: COS=0.488, DIST_SIM=0.000, AVG_DIST=5.05, PENALTY=0.317, FINAL=0.093
#    🔍 HYBRID DEBUG: COS=0.517, DIST_SIM=0.000, AVG_DIST=5.11, PENALTY=0.298, FINAL=0.092
#    🔍 HYBRID DEBUG: COS=0.538, DIST_SIM=0.000, AVG_DIST=8.44, PENALTY=0.100, FINAL=0.032
#    🔍 HYBRID DEBUG: COS=0.682, DIST_SIM=0.000, AVG_DIST=5.23, PENALTY=0.257, FINAL=0.105
#    🔍 HYBRID DEBUG: COS=0.657, DIST_SIM=0.000, AVG_DIST=4.78, PENALTY=0.408, FINAL=0.161
#    🔍 HYBRID DEBUG: COS=0.703, DIST_SIM=0.000, AVG_DIST=4.67, PENALTY=0.443, FINAL=0.187
#    🔍 HYBRID DEBUG: COS=0.678, DIST_SIM=0.000, AVG_DIST=5.25, PENALTY=0.250, FINAL=0.102
#    🔍 HYBRID DEBUG: COS=0.741, DIST_SIM=0.000, AVG_DIST=4.77, PENALTY=0.411, FINAL=0.183
#    🔍 HYBRID DEBUG: COS=0.757, DIST_SIM=0.000, AVG_DIST=8.53, PENALTY=0.100, FINAL=0.045
#    🔍 HYBRID DEBUG: COS=0.749, DIST_SIM=0.000, AVG_DIST=9.98, PENALTY=0.100, FINAL=0.045
#    🔍 HYBRID DEBUG: COS=0.786, DIST_SIM=0.000, AVG_DIST=4.90, PENALTY=0.366, FINAL=0.173
#    🔍 HYBRID DEBUG: COS=0.801, DIST_SIM=0.000, AVG_DIST=4.93, PENALTY=0.358, FINAL=0.172
#    🔍 HYBRID DEBUG: COS=0.844, DIST_SIM=0.000, AVG_DIST=4.88, PENALTY=0.374, FINAL=0.190
#    🔍 HYBRID DEBUG: COS=0.852, DIST_SIM=0.000, AVG_DIST=4.86, PENALTY=0.378, FINAL=0.193
#    🔍 HYBRID DEBUG: COS=0.846, DIST_SIM=0.000, AVG_DIST=4.83, PENALTY=0.390, FINAL=0.198
#    🔍 HYBRID DEBUG: COS=0.849, DIST_SIM=0.000, AVG_DIST=4.83, PENALTY=0.391, FINAL=0.199
#    🔍 HYBRID DEBUG: COS=0.845, DIST_SIM=0.000, AVG_DIST=4.79, PENALTY=0.402, FINAL=0.204
#    🔍 HYBRID DEBUG: COS=0.834, DIST_SIM=0.000, AVG_DIST=4.81, PENALTY=0.398, FINAL=0.199
#    🔍 HYBRID DEBUG: COS=0.855, DIST_SIM=0.000, AVG_DIST=4.74, PENALTY=0.420, FINAL=0.215
#    🔍 HYBRID DEBUG: COS=0.849, DIST_SIM=0.000, AVG_DIST=4.74, PENALTY=0.419, FINAL=0.214
#    🔍 HYBRID DEBUG: COS=0.945, DIST_SIM=0.000, AVG_DIST=4.75, PENALTY=0.418, FINAL=0.237
#    🔍 HYBRID DEBUG: COS=0.925, DIST_SIM=0.000, AVG_DIST=4.75, PENALTY=0.416, FINAL=0.231
#    🔍 HYBRID DEBUG: COS=0.967, DIST_SIM=0.000, AVG_DIST=4.79, PENALTY=0.403, FINAL=0.234
#    🔍 HYBRID DEBUG: COS=0.970, DIST_SIM=0.000, AVG_DIST=4.80, PENALTY=0.399, FINAL=0.232
#  MATCH STARTED at frame 231 (6.06s)! Step: 3, Similarity: 0.5950
#     Pose detected and normalized
#    Step 'San: Turn & Right Lower Block' match detected
#     POSE COMPARISON for 'San: Turn & Right Lower Block':
#    ============================================================
#    Joint        User Pose          Reference          Difference
#    ------------------------------------------------------------
#    Left wrist   (7.71, 2.34)       (5.66, 0.93)       2.499    ⚠️
#    Right wrist  (2.53, -6.51)      (1.23, -4.76)      2.179    ⚠️
#    Left elbow   (9.96, 3.44)       (7.43, 2.05)       2.885    ⚠️
#    Right elbow  (7.77, -4.94)      (4.44, -3.36)      3.683    ⚠️
#    Left knee    (-9.41, 3.18)      (-6.25, 2.58)      3.211    ⚠️
#    Right knee   (-6.73, -4.70)     (-4.49, -3.14)     2.724    ⚠️
#    ------------------------------------------------------------
#    Average difference: 2.864 ⚠️  GOOD MATCH
#  Step 3 COMPLETED (San: Turn & Right Lower Block) - Similarity: 0.554 at 6.09s (held for 0.03s)
#     Pose detected and normalized
#    Step 'San: Turn & Right Lower Block' processed successfully
#     POSE COMPARISON for 'San: Turn & Right Lower Block':
#    ============================================================
#    Joint        User Pose          Reference          Difference
#    ------------------------------------------------------------
#    Left wrist   (8.01, 2.35)       (5.66, 0.93)       2.754    ⚠️
#    Right wrist  (2.64, -6.68)      (1.23, -4.76)      2.381    ⚠️
#    Left elbow   (10.49, 3.63)      (7.43, 2.05)       3.442    ⚠️
#    Right elbow  (7.87, -5.08)      (4.44, -3.36)      3.834    ⚠️
#    Left knee    (-9.64, 3.29)      (-6.25, 2.58)      3.461    ⚠️
#    Right knee   (-6.88, -4.86)     (-4.49, -3.14)     2.936    ⚠️
#    ------------------------------------------------------------
#    Average difference: 3.134 ⚠️  GOOD MATCH
# --------------------------------------------------------------------------------
#    🔍 HYBRID DEBUG: COS=0.939, DIST_SIM=0.000, AVG_DIST=6.50, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.936, DIST_SIM=0.000, AVG_DIST=6.64, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.920, DIST_SIM=0.000, AVG_DIST=7.80, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.924, DIST_SIM=0.000, AVG_DIST=7.84, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.927, DIST_SIM=0.000, AVG_DIST=8.23, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.916, DIST_SIM=0.000, AVG_DIST=8.39, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.918, DIST_SIM=0.000, AVG_DIST=8.38, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.916, DIST_SIM=0.000, AVG_DIST=8.36, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.912, DIST_SIM=0.000, AVG_DIST=8.24, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.914, DIST_SIM=0.000, AVG_DIST=8.26, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.911, DIST_SIM=0.000, AVG_DIST=8.24, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.913, DIST_SIM=0.000, AVG_DIST=8.28, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.915, DIST_SIM=0.000, AVG_DIST=8.26, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.917, DIST_SIM=0.000, AVG_DIST=8.24, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.919, DIST_SIM=0.000, AVG_DIST=8.20, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.919, DIST_SIM=0.000, AVG_DIST=8.17, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.922, DIST_SIM=0.000, AVG_DIST=8.14, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.923, DIST_SIM=0.000, AVG_DIST=8.12, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.923, DIST_SIM=0.000, AVG_DIST=8.07, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.923, DIST_SIM=0.000, AVG_DIST=8.03, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.923, DIST_SIM=0.000, AVG_DIST=8.00, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.922, DIST_SIM=0.000, AVG_DIST=7.98, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.923, DIST_SIM=0.000, AVG_DIST=7.91, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.924, DIST_SIM=0.000, AVG_DIST=7.86, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.926, DIST_SIM=0.000, AVG_DIST=7.75, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.927, DIST_SIM=0.000, AVG_DIST=7.68, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.927, DIST_SIM=0.000, AVG_DIST=7.61, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.927, DIST_SIM=0.000, AVG_DIST=7.57, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.926, DIST_SIM=0.000, AVG_DIST=7.51, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.926, DIST_SIM=0.000, AVG_DIST=7.50, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.926, DIST_SIM=0.000, AVG_DIST=7.49, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.926, DIST_SIM=0.000, AVG_DIST=7.48, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.924, DIST_SIM=0.000, AVG_DIST=7.48, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.924, DIST_SIM=0.000, AVG_DIST=7.47, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.924, DIST_SIM=0.000, AVG_DIST=7.46, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.925, DIST_SIM=0.000, AVG_DIST=7.45, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.926, DIST_SIM=0.000, AVG_DIST=7.44, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.926, DIST_SIM=0.000, AVG_DIST=7.44, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.926, DIST_SIM=0.000, AVG_DIST=7.44, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.927, DIST_SIM=0.000, AVG_DIST=7.44, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.929, DIST_SIM=0.000, AVG_DIST=7.44, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.930, DIST_SIM=0.000, AVG_DIST=7.44, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.931, DIST_SIM=0.000, AVG_DIST=7.44, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.931, DIST_SIM=0.000, AVG_DIST=7.43, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.939, DIST_SIM=0.000, AVG_DIST=7.46, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.939, DIST_SIM=0.000, AVG_DIST=7.49, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.945, DIST_SIM=0.000, AVG_DIST=7.42, PENALTY=0.100, FINAL=0.057
#    🔍 HYBRID DEBUG: COS=0.946, DIST_SIM=0.000, AVG_DIST=7.39, PENALTY=0.100, FINAL=0.057
#    🔍 HYBRID DEBUG: COS=0.950, DIST_SIM=0.000, AVG_DIST=7.21, PENALTY=0.100, FINAL=0.057
#    🔍 HYBRID DEBUG: COS=0.952, DIST_SIM=0.000, AVG_DIST=7.15, PENALTY=0.100, FINAL=0.057
#    🔍 HYBRID DEBUG: COS=0.957, DIST_SIM=0.000, AVG_DIST=5.83, PENALTY=0.100, FINAL=0.057
#    🔍 HYBRID DEBUG: COS=0.957, DIST_SIM=0.000, AVG_DIST=5.61, PENALTY=0.129, FINAL=0.074
#    🔍 HYBRID DEBUG: COS=0.960, DIST_SIM=0.000, AVG_DIST=12.07, PENALTY=0.100, FINAL=0.058
#    🔍 HYBRID DEBUG: COS=0.946, DIST_SIM=0.000, AVG_DIST=12.06, PENALTY=0.100, FINAL=0.057
#    🔍 HYBRID DEBUG: COS=0.935, DIST_SIM=0.000, AVG_DIST=12.03, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.928, DIST_SIM=0.000, AVG_DIST=12.02, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.925, DIST_SIM=0.000, AVG_DIST=11.99, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.913, DIST_SIM=0.000, AVG_DIST=11.99, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.925, DIST_SIM=0.000, AVG_DIST=11.97, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.846, DIST_SIM=0.000, AVG_DIST=11.96, PENALTY=0.100, FINAL=0.051
#    🔍 HYBRID DEBUG: COS=0.597, DIST_SIM=0.000, AVG_DIST=11.98, PENALTY=0.100, FINAL=0.036
#    🔍 HYBRID DEBUG: COS=0.815, DIST_SIM=0.000, AVG_DIST=11.98, PENALTY=0.100, FINAL=0.049
#    🔍 HYBRID DEBUG: COS=0.857, DIST_SIM=0.000, AVG_DIST=12.07, PENALTY=0.100, FINAL=0.051
#    🔍 HYBRID DEBUG: COS=0.833, DIST_SIM=0.000, AVG_DIST=12.09, PENALTY=0.100, FINAL=0.050
#    🔍 HYBRID DEBUG: COS=0.855, DIST_SIM=0.000, AVG_DIST=12.17, PENALTY=0.100, FINAL=0.051
#    🔍 HYBRID DEBUG: COS=0.862, DIST_SIM=0.000, AVG_DIST=12.17, PENALTY=0.100, FINAL=0.052
#    🔍 HYBRID DEBUG: COS=0.873, DIST_SIM=0.000, AVG_DIST=12.27, PENALTY=0.100, FINAL=0.052
#    🔍 HYBRID DEBUG: COS=0.874, DIST_SIM=0.000, AVG_DIST=12.29, PENALTY=0.100, FINAL=0.052
#    🔍 HYBRID DEBUG: COS=0.851, DIST_SIM=0.000, AVG_DIST=12.33, PENALTY=0.100, FINAL=0.051
#    🔍 HYBRID DEBUG: COS=0.849, DIST_SIM=0.000, AVG_DIST=12.33, PENALTY=0.100, FINAL=0.051
#    🔍 HYBRID DEBUG: COS=0.871, DIST_SIM=0.000, AVG_DIST=12.31, PENALTY=0.100, FINAL=0.052
#    🔍 HYBRID DEBUG: COS=0.878, DIST_SIM=0.000, AVG_DIST=12.26, PENALTY=0.100, FINAL=0.053
#    🔍 HYBRID DEBUG: COS=0.913, DIST_SIM=0.000, AVG_DIST=12.03, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.915, DIST_SIM=0.000, AVG_DIST=12.10, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.928, DIST_SIM=0.000, AVG_DIST=12.21, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.944, DIST_SIM=0.000, AVG_DIST=12.02, PENALTY=0.100, FINAL=0.057
#    🔍 HYBRID DEBUG: COS=0.901, DIST_SIM=0.000, AVG_DIST=11.62, PENALTY=0.100, FINAL=0.054
#    🔍 HYBRID DEBUG: COS=0.853, DIST_SIM=0.000, AVG_DIST=5.90, PENALTY=0.100, FINAL=0.051
#    🔍 HYBRID DEBUG: COS=0.856, DIST_SIM=0.000, AVG_DIST=7.28, PENALTY=0.100, FINAL=0.051
#    🔍 HYBRID DEBUG: COS=0.891, DIST_SIM=0.000, AVG_DIST=7.14, PENALTY=0.100, FINAL=0.053
#    🔍 HYBRID DEBUG: COS=0.931, DIST_SIM=0.000, AVG_DIST=6.48, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.927, DIST_SIM=0.000, AVG_DIST=5.95, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.919, DIST_SIM=0.000, AVG_DIST=5.80, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.906, DIST_SIM=0.000, AVG_DIST=5.81, PENALTY=0.100, FINAL=0.054
#    🔍 HYBRID DEBUG: COS=0.907, DIST_SIM=0.000, AVG_DIST=5.59, PENALTY=0.137, FINAL=0.075
#    🔍 HYBRID DEBUG: COS=0.903, DIST_SIM=0.000, AVG_DIST=5.50, PENALTY=0.166, FINAL=0.090
#    🔍 HYBRID DEBUG: COS=0.917, DIST_SIM=0.000, AVG_DIST=5.28, PENALTY=0.240, FINAL=0.132
#    🔍 HYBRID DEBUG: COS=0.926, DIST_SIM=0.000, AVG_DIST=5.31, PENALTY=0.228, FINAL=0.127
#    🔍 HYBRID DEBUG: COS=0.910, DIST_SIM=0.000, AVG_DIST=5.15, PENALTY=0.282, FINAL=0.154
#    🔍 HYBRID DEBUG: COS=0.914, DIST_SIM=0.000, AVG_DIST=5.13, PENALTY=0.289, FINAL=0.158
#    🔍 HYBRID DEBUG: COS=0.872, DIST_SIM=0.000, AVG_DIST=4.99, PENALTY=0.335, FINAL=0.176
#    🔍 HYBRID DEBUG: COS=0.902, DIST_SIM=0.000, AVG_DIST=4.85, PENALTY=0.383, FINAL=0.207
#    🔍 HYBRID DEBUG: COS=0.933, DIST_SIM=0.000, AVG_DIST=4.56, PENALTY=0.480, FINAL=0.269
#    🔍 HYBRID DEBUG: COS=0.864, DIST_SIM=0.000, AVG_DIST=4.61, PENALTY=0.463, FINAL=0.240
#    🔍 HYBRID DEBUG: COS=0.948, DIST_SIM=0.000, AVG_DIST=11.69, PENALTY=0.100, FINAL=0.057
#    🔍 HYBRID DEBUG: COS=0.950, DIST_SIM=0.000, AVG_DIST=11.68, PENALTY=0.100, FINAL=0.057
#    🔍 HYBRID DEBUG: COS=0.931, DIST_SIM=0.000, AVG_DIST=11.80, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.931, DIST_SIM=0.000, AVG_DIST=11.82, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.924, DIST_SIM=0.000, AVG_DIST=11.81, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.916, DIST_SIM=0.000, AVG_DIST=11.79, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.961, DIST_SIM=0.000, AVG_DIST=11.74, PENALTY=0.100, FINAL=0.058
#    🔍 HYBRID DEBUG: COS=0.965, DIST_SIM=0.000, AVG_DIST=11.74, PENALTY=0.100, FINAL=0.058
#    🔍 HYBRID DEBUG: COS=0.981, DIST_SIM=0.000, AVG_DIST=11.77, PENALTY=0.100, FINAL=0.059
#    🔍 HYBRID DEBUG: COS=0.968, DIST_SIM=0.000, AVG_DIST=11.75, PENALTY=0.100, FINAL=0.058
#    🔍 HYBRID DEBUG: COS=0.993, DIST_SIM=0.000, AVG_DIST=11.76, PENALTY=0.100, FINAL=0.060
#    🔍 HYBRID DEBUG: COS=0.994, DIST_SIM=0.000, AVG_DIST=11.77, PENALTY=0.100, FINAL=0.060
#    🔍 HYBRID DEBUG: COS=0.997, DIST_SIM=0.000, AVG_DIST=11.77, PENALTY=0.100, FINAL=0.060
#    🔍 HYBRID DEBUG: COS=0.995, DIST_SIM=0.000, AVG_DIST=11.77, PENALTY=0.100, FINAL=0.060
#  MATCH STARTED at frame 345 (9.05s)! Step: 4, Similarity: 0.8682
#     Pose detected and normalized
#    Step 'Shi: Right Hammerfist Strike' match detected
#     POSE COMPARISON for 'Shi: Right Hammerfist Strike':
#    ============================================================
#    Joint        User Pose          Reference          Difference
#    ------------------------------------------------------------
#    Left wrist   (9.15, 2.47)       (8.34, 2.21)       0.851    ✅
#    Right wrist  (18.20, -11.34)    (17.50, -10.27)    1.271    ✅
#    Left elbow   (12.70, 4.26)      (12.01, 3.88)      0.786    ✅
#    Right elbow  (15.70, -7.66)     (15.08, -7.13)     0.817    ✅
#    Left knee    (-12.15, 3.88)     (-11.27, 3.79)     0.889    ✅
#    Right knee   (-9.56, -5.71)     (-8.39, -5.52)     1.185    ✅
#    ------------------------------------------------------------
#    Average difference: 0.967 ✅ EXCELLENT MATCH!
#  Step 4 COMPLETED (Shi: Right Hammerfist Strike) - Similarity: 0.868 at 9.08s (held for 0.03s)
#     Pose detected and normalized
#    Step 'Shi: Right Hammerfist Strike' processed successfully
#     POSE COMPARISON for 'Shi: Right Hammerfist Strike':
#    ============================================================
#    Joint        User Pose          Reference          Difference
#    ------------------------------------------------------------
#    Left wrist   (9.14, 2.44)       (8.34, 2.21)       0.838    ✅
#    Right wrist  (18.34, -11.32)    (17.50, -10.27)    1.343    ✅
#    Left elbow   (12.71, 4.18)      (12.01, 3.88)      0.766    ✅
#    Right elbow  (15.57, -7.66)     (15.08, -7.13)     0.718    ✅
#    Left knee    (-12.18, 3.90)     (-11.27, 3.79)     0.918    ✅
#    Right knee   (-9.56, -5.70)     (-8.39, -5.52)     1.183    ✅
#    ------------------------------------------------------------
#    Average difference: 0.961 ✅ EXCELLENT MATCH!
# --------------------------------------------------------------------------------
#    🔍 HYBRID DEBUG: COS=0.338, DIST_SIM=0.000, AVG_DIST=12.66, PENALTY=0.100, FINAL=0.020
#    🔍 HYBRID DEBUG: COS=0.326, DIST_SIM=0.000, AVG_DIST=12.49, PENALTY=0.100, FINAL=0.020
#    🔍 HYBRID DEBUG: COS=0.332, DIST_SIM=0.000, AVG_DIST=12.58, PENALTY=0.100, FINAL=0.020
#    🔍 HYBRID DEBUG: COS=0.348, DIST_SIM=0.000, AVG_DIST=12.55, PENALTY=0.100, FINAL=0.021
#    🔍 HYBRID DEBUG: COS=0.363, DIST_SIM=0.000, AVG_DIST=12.78, PENALTY=0.100, FINAL=0.022
#    🔍 HYBRID DEBUG: COS=0.371, DIST_SIM=0.000, AVG_DIST=13.10, PENALTY=0.100, FINAL=0.022
#    🔍 HYBRID DEBUG: COS=0.381, DIST_SIM=0.000, AVG_DIST=13.51, PENALTY=0.100, FINAL=0.023
#    🔍 HYBRID DEBUG: COS=0.384, DIST_SIM=0.000, AVG_DIST=13.69, PENALTY=0.100, FINAL=0.023
#    🔍 HYBRID DEBUG: COS=0.379, DIST_SIM=0.000, AVG_DIST=13.69, PENALTY=0.100, FINAL=0.023
#    🔍 HYBRID DEBUG: COS=0.376, DIST_SIM=0.000, AVG_DIST=13.69, PENALTY=0.100, FINAL=0.023
#    🔍 HYBRID DEBUG: COS=0.381, DIST_SIM=0.000, AVG_DIST=13.69, PENALTY=0.100, FINAL=0.023
#    🔍 HYBRID DEBUG: COS=0.386, DIST_SIM=0.000, AVG_DIST=13.69, PENALTY=0.100, FINAL=0.023
#    🔍 HYBRID DEBUG: COS=0.392, DIST_SIM=0.000, AVG_DIST=13.69, PENALTY=0.100, FINAL=0.024
#    🔍 HYBRID DEBUG: COS=0.395, DIST_SIM=0.000, AVG_DIST=13.69, PENALTY=0.100, FINAL=0.024
#    🔍 HYBRID DEBUG: COS=0.391, DIST_SIM=0.000, AVG_DIST=13.70, PENALTY=0.100, FINAL=0.023
#    🔍 HYBRID DEBUG: COS=0.389, DIST_SIM=0.000, AVG_DIST=13.70, PENALTY=0.100, FINAL=0.023
#    🔍 HYBRID DEBUG: COS=0.393, DIST_SIM=0.000, AVG_DIST=13.70, PENALTY=0.100, FINAL=0.024
#    🔍 HYBRID DEBUG: COS=0.395, DIST_SIM=0.000, AVG_DIST=13.70, PENALTY=0.100, FINAL=0.024
#    🔍 HYBRID DEBUG: COS=0.393, DIST_SIM=0.000, AVG_DIST=13.70, PENALTY=0.100, FINAL=0.024
#    🔍 HYBRID DEBUG: COS=0.392, DIST_SIM=0.000, AVG_DIST=13.70, PENALTY=0.100, FINAL=0.024
#    🔍 HYBRID DEBUG: COS=0.376, DIST_SIM=0.000, AVG_DIST=13.69, PENALTY=0.100, FINAL=0.023
#    🔍 HYBRID DEBUG: COS=0.365, DIST_SIM=0.000, AVG_DIST=13.69, PENALTY=0.100, FINAL=0.022
#    🔍 HYBRID DEBUG: COS=0.341, DIST_SIM=0.000, AVG_DIST=13.69, PENALTY=0.100, FINAL=0.020
#    🔍 HYBRID DEBUG: COS=0.338, DIST_SIM=0.000, AVG_DIST=13.69, PENALTY=0.100, FINAL=0.020
#    🔍 HYBRID DEBUG: COS=0.357, DIST_SIM=0.000, AVG_DIST=13.69, PENALTY=0.100, FINAL=0.021
#    🔍 HYBRID DEBUG: COS=0.375, DIST_SIM=0.000, AVG_DIST=13.69, PENALTY=0.100, FINAL=0.023
#    🔍 HYBRID DEBUG: COS=0.374, DIST_SIM=0.000, AVG_DIST=13.68, PENALTY=0.100, FINAL=0.022
#    🔍 HYBRID DEBUG: COS=0.373, DIST_SIM=0.000, AVG_DIST=13.68, PENALTY=0.100, FINAL=0.022
#    🔍 HYBRID DEBUG: COS=0.383, DIST_SIM=0.000, AVG_DIST=13.68, PENALTY=0.100, FINAL=0.023
#    🔍 HYBRID DEBUG: COS=0.384, DIST_SIM=0.000, AVG_DIST=13.68, PENALTY=0.100, FINAL=0.023
#    🔍 HYBRID DEBUG: COS=0.397, DIST_SIM=0.000, AVG_DIST=13.68, PENALTY=0.100, FINAL=0.024
#    🔍 HYBRID DEBUG: COS=0.399, DIST_SIM=0.000, AVG_DIST=13.68, PENALTY=0.100, FINAL=0.024
#    🔍 HYBRID DEBUG: COS=0.408, DIST_SIM=0.000, AVG_DIST=13.67, PENALTY=0.100, FINAL=0.025
#    🔍 HYBRID DEBUG: COS=0.412, DIST_SIM=0.000, AVG_DIST=13.67, PENALTY=0.100, FINAL=0.025
#    🔍 HYBRID DEBUG: COS=0.434, DIST_SIM=0.000, AVG_DIST=13.67, PENALTY=0.100, FINAL=0.026
#    🔍 HYBRID DEBUG: COS=0.439, DIST_SIM=0.000, AVG_DIST=13.67, PENALTY=0.100, FINAL=0.026
#    🔍 HYBRID DEBUG: COS=0.440, DIST_SIM=0.000, AVG_DIST=13.67, PENALTY=0.100, FINAL=0.026
#    🔍 HYBRID DEBUG: COS=0.447, DIST_SIM=0.000, AVG_DIST=13.66, PENALTY=0.100, FINAL=0.027
#    🔍 HYBRID DEBUG: COS=0.458, DIST_SIM=0.000, AVG_DIST=13.66, PENALTY=0.100, FINAL=0.027
#    🔍 HYBRID DEBUG: COS=0.480, DIST_SIM=0.000, AVG_DIST=13.66, PENALTY=0.100, FINAL=0.029
#    🔍 HYBRID DEBUG: COS=0.471, DIST_SIM=0.000, AVG_DIST=13.91, PENALTY=0.100, FINAL=0.028
#    🔍 HYBRID DEBUG: COS=0.528, DIST_SIM=0.000, AVG_DIST=12.36, PENALTY=0.100, FINAL=0.032
#    🔍 HYBRID DEBUG: COS=0.506, DIST_SIM=0.000, AVG_DIST=12.48, PENALTY=0.100, FINAL=0.030
#    🔍 HYBRID DEBUG: COS=0.512, DIST_SIM=0.000, AVG_DIST=12.05, PENALTY=0.100, FINAL=0.031
#    🔍 HYBRID DEBUG: COS=0.508, DIST_SIM=0.000, AVG_DIST=12.02, PENALTY=0.100, FINAL=0.030
#    🔍 HYBRID DEBUG: COS=0.512, DIST_SIM=0.000, AVG_DIST=11.77, PENALTY=0.100, FINAL=0.031
#    🔍 HYBRID DEBUG: COS=0.557, DIST_SIM=0.000, AVG_DIST=11.74, PENALTY=0.100, FINAL=0.033
#    🔍 HYBRID DEBUG: COS=0.551, DIST_SIM=0.000, AVG_DIST=11.80, PENALTY=0.100, FINAL=0.033
#    🔍 HYBRID DEBUG: COS=0.557, DIST_SIM=0.000, AVG_DIST=11.84, PENALTY=0.100, FINAL=0.033
#    🔍 HYBRID DEBUG: COS=0.550, DIST_SIM=0.000, AVG_DIST=11.84, PENALTY=0.100, FINAL=0.033
#    🔍 HYBRID DEBUG: COS=0.544, DIST_SIM=0.000, AVG_DIST=11.87, PENALTY=0.100, FINAL=0.033
#    🔍 HYBRID DEBUG: COS=0.553, DIST_SIM=0.000, AVG_DIST=11.81, PENALTY=0.100, FINAL=0.033
#    🔍 HYBRID DEBUG: COS=0.570, DIST_SIM=0.000, AVG_DIST=11.79, PENALTY=0.100, FINAL=0.034
#    🔍 HYBRID DEBUG: COS=0.572, DIST_SIM=0.000, AVG_DIST=11.71, PENALTY=0.100, FINAL=0.034
#    🔍 HYBRID DEBUG: COS=0.567, DIST_SIM=0.000, AVG_DIST=11.69, PENALTY=0.100, FINAL=0.034
#    🔍 HYBRID DEBUG: COS=0.620, DIST_SIM=0.000, AVG_DIST=11.56, PENALTY=0.100, FINAL=0.037
#    🔍 HYBRID DEBUG: COS=0.643, DIST_SIM=0.000, AVG_DIST=11.50, PENALTY=0.100, FINAL=0.039
#    🔍 HYBRID DEBUG: COS=0.651, DIST_SIM=0.000, AVG_DIST=11.32, PENALTY=0.100, FINAL=0.039
#    🔍 HYBRID DEBUG: COS=0.675, DIST_SIM=0.000, AVG_DIST=11.23, PENALTY=0.100, FINAL=0.040
#    🔍 HYBRID DEBUG: COS=0.748, DIST_SIM=0.000, AVG_DIST=11.00, PENALTY=0.100, FINAL=0.045
#    🔍 HYBRID DEBUG: COS=0.777, DIST_SIM=0.000, AVG_DIST=10.91, PENALTY=0.100, FINAL=0.047
#    🔍 HYBRID DEBUG: COS=0.839, DIST_SIM=0.000, AVG_DIST=10.71, PENALTY=0.100, FINAL=0.050
#    🔍 HYBRID DEBUG: COS=0.833, DIST_SIM=0.000, AVG_DIST=10.67, PENALTY=0.100, FINAL=0.050
#    🔍 HYBRID DEBUG: COS=0.850, DIST_SIM=0.000, AVG_DIST=11.11, PENALTY=0.100, FINAL=0.051
#    🔍 HYBRID DEBUG: COS=0.843, DIST_SIM=0.000, AVG_DIST=10.74, PENALTY=0.100, FINAL=0.051
#    🔍 HYBRID DEBUG: COS=0.851, DIST_SIM=0.000, AVG_DIST=13.59, PENALTY=0.100, FINAL=0.051
#    🔍 HYBRID DEBUG: COS=0.858, DIST_SIM=0.000, AVG_DIST=13.59, PENALTY=0.100, FINAL=0.051
#    🔍 HYBRID DEBUG: COS=0.843, DIST_SIM=0.000, AVG_DIST=13.59, PENALTY=0.100, FINAL=0.051
#    🔍 HYBRID DEBUG: COS=0.820, DIST_SIM=0.000, AVG_DIST=13.61, PENALTY=0.100, FINAL=0.049
#    🔍 HYBRID DEBUG: COS=0.843, DIST_SIM=0.000, AVG_DIST=13.58, PENALTY=0.100, FINAL=0.051
#    🔍 HYBRID DEBUG: COS=0.838, DIST_SIM=0.000, AVG_DIST=13.56, PENALTY=0.100, FINAL=0.050
#    🔍 HYBRID DEBUG: COS=0.903, DIST_SIM=0.000, AVG_DIST=13.47, PENALTY=0.100, FINAL=0.054
#    🔍 HYBRID DEBUG: COS=0.900, DIST_SIM=0.000, AVG_DIST=13.47, PENALTY=0.100, FINAL=0.054
#    🔍 HYBRID DEBUG: COS=0.900, DIST_SIM=0.000, AVG_DIST=13.38, PENALTY=0.100, FINAL=0.054
#    🔍 HYBRID DEBUG: COS=0.921, DIST_SIM=0.000, AVG_DIST=13.34, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.957, DIST_SIM=0.000, AVG_DIST=13.46, PENALTY=0.100, FINAL=0.057
#    🔍 HYBRID DEBUG: COS=0.939, DIST_SIM=0.000, AVG_DIST=13.46, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.729, DIST_SIM=0.000, AVG_DIST=13.39, PENALTY=0.100, FINAL=0.044
#  MATCH STARTED at frame 428 (11.23s)! Step: 5, Similarity: 0.6124
#     Pose detected and normalized
#    Step 'Go: Left Lunge Punch' match detected
#     POSE COMPARISON for 'Go: Left Lunge Punch':
#    ============================================================
#    Joint        User Pose          Reference          Difference
#    ------------------------------------------------------------
#    Left wrist   (16.29, -10.67)    (18.27, -11.45)    2.124    ⚠️
#    Right wrist  (8.15, 0.90)       (8.58, 2.43)       1.594    ✅
#    Left elbow   (15.83, -7.05)     (17.87, -7.68)     2.141    ⚠️
#    Right elbow  (10.92, 3.27)      (13.26, 4.50)      2.644    ⚠️
#    Left knee    (-9.36, -5.24)     (-10.48, -6.31)    1.552    ✅
#    Right knee   (-10.23, 0.51)     (-11.74, 2.80)     2.735    ⚠️
#    ------------------------------------------------------------
#    Average difference: 2.132 ⚠️  GOOD MATCH
#  Step 5 COMPLETED (Go: Left Lunge Punch) - Similarity: 0.676 at 11.25s (held for 0.03s)
#     Pose detected and normalized
#    Step 'Go: Left Lunge Punch' processed successfully
#     POSE COMPARISON for 'Go: Left Lunge Punch':
#    ============================================================
#    Joint        User Pose          Reference          Difference
# ...
#    🔍 HYBRID DEBUG: COS=0.777, DIST_SIM=0.000, AVG_DIST=9.55, PENALTY=0.100, FINAL=0.047
#    🔍 HYBRID DEBUG: COS=0.806, DIST_SIM=0.000, AVG_DIST=10.12, PENALTY=0.100, FINAL=0.048
#    🔍 HYBRID DEBUG: COS=0.805, DIST_SIM=0.000, AVG_DIST=10.94, PENALTY=0.100, FINAL=0.048
#    🔍 HYBRID DEBUG: COS=0.805, DIST_SIM=0.000, AVG_DIST=11.53, PENALTY=0.100, FINAL=0.048
#    🔍 HYBRID DEBUG: COS=0.813, DIST_SIM=0.000, AVG_DIST=11.34, PENALTY=0.100, FINAL=0.049
#    🔍 HYBRID DEBUG: COS=0.812, DIST_SIM=0.000, AVG_DIST=10.68, PENALTY=0.100, FINAL=0.049
#    🔍 HYBRID DEBUG: COS=0.818, DIST_SIM=0.000, AVG_DIST=10.78, PENALTY=0.100, FINAL=0.049
#    🔍 HYBRID DEBUG: COS=0.821, DIST_SIM=0.000, AVG_DIST=10.27, PENALTY=0.100, FINAL=0.049
#    🔍 HYBRID DEBUG: COS=0.828, DIST_SIM=0.000, AVG_DIST=10.11, PENALTY=0.100, FINAL=0.050
#  MATCH STARTED at frame 867 (22.74s)! Step: 15, Similarity: 0.8577
#     Pose detected and normalized
#    Step 'Ju Go: Right Lunge Punch' match detected
#     POSE COMPARISON for 'Ju Go: Right Lunge Punch':
#    ============================================================
#    Joint        User Pose          Reference          Difference
#    ------------------------------------------------------------
#    Left wrist   (0.82, -0.13)      (1.21, -0.30)      0.424    ✅
#    Right wrist  (0.83, 0.52)       (1.70, -0.02)      1.029    ✅
#    Left elbow   (1.27, -0.35)      (1.31, -0.50)      0.156    ✅
#    Right elbow  (1.36, 0.56)       (1.47, 0.27)       0.315    ✅
#    Left knee    (-1.72, -0.23)     (-1.77, -0.40)     0.181    ✅
#    Right knee   (-1.51, 0.34)      (-1.37, 0.27)      0.157    ✅
#    ------------------------------------------------------------
#    Average difference: 0.377 ✅ EXCELLENT MATCH!
#  Step 15 COMPLETED (Ju Go: Right Lunge Punch) - Similarity: 0.877 at 22.77s (held for 0.03s)
#     Pose detected and normalized
#    Step 'Ju Go: Right Lunge Punch' processed successfully
#     POSE COMPARISON for 'Ju Go: Right Lunge Punch':
#    ============================================================
#    Joint        User Pose          Reference          Difference
#    ------------------------------------------------------------
#    Left wrist   (0.80, -0.15)      (1.21, -0.30)      0.433    ✅
#    Right wrist  (0.83, 0.43)       (1.70, -0.02)      0.980    ✅
#    Left elbow   (1.27, -0.38)      (1.31, -0.50)      0.125    ✅
#    Right elbow  (1.24, 0.57)       (1.47, 0.27)       0.382    ✅
#    Left knee    (-1.72, -0.26)     (-1.77, -0.40)     0.150    ✅
#    Right knee   (-1.35, 0.32)      (-1.37, 0.27)      0.055    ✅
#    ------------------------------------------------------------
#    Average difference: 0.354 ✅ EXCELLENT MATCH!
# --------------------------------------------------------------------------------
#    🔍 HYBRID DEBUG: COS=0.882, DIST_SIM=0.000, AVG_DIST=7.73, PENALTY=0.100, FINAL=0.053
#    🔍 HYBRID DEBUG: COS=0.890, DIST_SIM=0.000, AVG_DIST=7.74, PENALTY=0.100, FINAL=0.053
#    🔍 HYBRID DEBUG: COS=0.920, DIST_SIM=0.000, AVG_DIST=7.59, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.976, DIST_SIM=0.000, AVG_DIST=7.45, PENALTY=0.100, FINAL=0.059
#    🔍 HYBRID DEBUG: COS=0.972, DIST_SIM=0.000, AVG_DIST=7.35, PENALTY=0.100, FINAL=0.058
#    🔍 HYBRID DEBUG: COS=0.974, DIST_SIM=0.000, AVG_DIST=7.30, PENALTY=0.100, FINAL=0.058
#    🔍 HYBRID DEBUG: COS=0.944, DIST_SIM=0.000, AVG_DIST=7.26, PENALTY=0.100, FINAL=0.057
#    🔍 HYBRID DEBUG: COS=0.917, DIST_SIM=0.000, AVG_DIST=7.33, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.914, DIST_SIM=0.000, AVG_DIST=6.54, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.916, DIST_SIM=0.000, AVG_DIST=5.43, PENALTY=0.189, FINAL=0.104
#    🔍 HYBRID DEBUG: COS=0.910, DIST_SIM=0.000, AVG_DIST=5.27, PENALTY=0.243, FINAL=0.133
#    🔍 HYBRID DEBUG: COS=0.918, DIST_SIM=0.000, AVG_DIST=5.83, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.918, DIST_SIM=0.000, AVG_DIST=7.52, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.913, DIST_SIM=0.000, AVG_DIST=7.55, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.907, DIST_SIM=0.000, AVG_DIST=7.60, PENALTY=0.100, FINAL=0.054
#    🔍 HYBRID DEBUG: COS=0.909, DIST_SIM=0.000, AVG_DIST=7.61, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.908, DIST_SIM=0.000, AVG_DIST=7.62, PENALTY=0.100, FINAL=0.054
#    🔍 HYBRID DEBUG: COS=0.907, DIST_SIM=0.000, AVG_DIST=7.62, PENALTY=0.100, FINAL=0.054
#    🔍 HYBRID DEBUG: COS=0.905, DIST_SIM=0.000, AVG_DIST=7.61, PENALTY=0.100, FINAL=0.054
#    🔍 HYBRID DEBUG: COS=0.905, DIST_SIM=0.000, AVG_DIST=7.62, PENALTY=0.100, FINAL=0.054
#    🔍 HYBRID DEBUG: COS=0.908, DIST_SIM=0.000, AVG_DIST=7.62, PENALTY=0.100, FINAL=0.054
#    🔍 HYBRID DEBUG: COS=0.912, DIST_SIM=0.000, AVG_DIST=7.61, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.914, DIST_SIM=0.000, AVG_DIST=7.64, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.915, DIST_SIM=0.000, AVG_DIST=7.69, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.917, DIST_SIM=0.000, AVG_DIST=7.69, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.917, DIST_SIM=0.000, AVG_DIST=7.70, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.920, DIST_SIM=0.000, AVG_DIST=7.72, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.924, DIST_SIM=0.000, AVG_DIST=7.66, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.922, DIST_SIM=0.000, AVG_DIST=7.60, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.922, DIST_SIM=0.000, AVG_DIST=7.61, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.924, DIST_SIM=0.000, AVG_DIST=7.57, PENALTY=0.100, FINAL=0.055
#    🔍 HYBRID DEBUG: COS=0.934, DIST_SIM=0.000, AVG_DIST=7.62, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.950, DIST_SIM=0.000, AVG_DIST=7.75, PENALTY=0.100, FINAL=0.057
#    🔍 HYBRID DEBUG: COS=0.958, DIST_SIM=0.000, AVG_DIST=7.74, PENALTY=0.100, FINAL=0.057
#    🔍 HYBRID DEBUG: COS=0.945, DIST_SIM=0.000, AVG_DIST=7.71, PENALTY=0.100, FINAL=0.057
#    🔍 HYBRID DEBUG: COS=0.974, DIST_SIM=0.000, AVG_DIST=7.70, PENALTY=0.100, FINAL=0.058
#    🔍 HYBRID DEBUG: COS=0.972, DIST_SIM=0.000, AVG_DIST=7.75, PENALTY=0.100, FINAL=0.058
#    🔍 HYBRID DEBUG: COS=0.979, DIST_SIM=0.000, AVG_DIST=7.75, PENALTY=0.100, FINAL=0.059
#    🔍 HYBRID DEBUG: COS=0.938, DIST_SIM=0.000, AVG_DIST=7.75, PENALTY=0.100, FINAL=0.056
#    🔍 HYBRID DEBUG: COS=0.953, DIST_SIM=0.000, AVG_DIST=7.78, PENALTY=0.100, FINAL=0.057
#    🔍 HYBRID DEBUG: COS=0.944, DIST_SIM=0.000, AVG_DIST=7.75, PENALTY=0.100, FINAL=0.057
#    🔍 HYBRID DEBUG: COS=0.938, DIST_SIM=0.000, AVG_DIST=7.80, PENALTY=0.100, FINAL=0.056
#  MATCH STARTED at frame 911 (23.90s)! Step: 16, Similarity: 0.7762
#     Pose detected and normalized
#    Step 'Ju Roku: Left Lunge Punch' match detected
#     POSE COMPARISON for 'Ju Roku: Left Lunge Punch':
#    ============================================================
#    Joint        User Pose          Reference          Difference
#    ------------------------------------------------------------
#    Left wrist   (8.03, -1.23)      (10.13, -1.50)     2.118    ⚠️
#    Right wrist  (8.92, 1.15)       (6.63, 2.56)       2.692    ⚠️
#    Left elbow   (9.21, -3.01)      (9.28, -2.66)      0.354    ✅
#    Right elbow  (8.51, 2.62)       (7.52, 4.36)       2.002    ⚠️
#    Left knee    (-8.52, -0.91)     (-8.20, -1.95)     1.091    ✅
#    Right knee   (-10.23, 2.44)     (-9.97, 2.44)      0.265    ✅
#    ------------------------------------------------------------
#    Average difference: 1.420 ✅ EXCELLENT MATCH!
#  Step 16 COMPLETED (Ju Roku: Left Lunge Punch) - Similarity: 0.696 at 23.92s (held for 0.03s)
#     Pose detected and normalized
#    Step 'Ju Roku: Left Lunge Punch' processed successfully
#     POSE COMPARISON for 'Ju Roku: Left Lunge Punch':
#    ============================================================
#    Joint        User Pose          Reference          Difference
#    ------------------------------------------------------------
#    Left wrist   (7.49, -0.80)      (10.13, -1.50)     2.729    ⚠️
#    Right wrist  (9.40, 1.15)       (6.63, 2.56)       3.107    ⚠️
#    Left elbow   (7.49, -2.27)      (9.28, -2.66)      1.832    ✅
#    Right elbow  (6.96, 2.62)       (7.52, 4.36)       1.820    ✅
#    Left knee    (-7.28, -0.96)     (-8.20, -1.95)     1.351    ✅
#    Right knee   (-8.71, 2.57)      (-9.97, 2.44)      1.262    ✅
#    ------------------------------------------------------------
#    Average difference: 2.017 ⚠️  GOOD MATCH
# --------------------------------------------------------------------------------
#    🔍 HYBRID DEBUG: COS=0.841, DIST_SIM=0.000, AVG_DIST=6.56, PENALTY=0.100, FINAL=0.050
#    🔍 HYBRID DEBUG: COS=0.846, DIST_SIM=0.000, AVG_DIST=6.56, PENALTY=0.100, FINAL=0.051
#    🔍 HYBRID DEBUG: COS=0.847, DIST_SIM=0.000, AVG_DIST=6.92, PENALTY=0.100, FINAL=0.051
#    🔍 HYBRID DEBUG: COS=0.845, DIST_SIM=0.000, AVG_DIST=6.96, PENALTY=0.100, FINAL=0.051
#    🔍 HYBRID DEBUG: COS=0.900, DIST_SIM=0.000, AVG_DIST=8.95, PENALTY=0.100, FINAL=0.054
#  MATCH STARTED at frame 918 (24.08s)! Step: 17, Similarity: 0.8438
#     Pose detected and normalized
#    Step 'Ju Shichi: Right Lunge Punch (2nd Kiai)' match detected
#     POSE COMPARISON for 'Ju Shichi: Right Lunge Punch (2nd Kiai)':
#    ============================================================
#    Joint        User Pose          Reference          Difference
#    ------------------------------------------------------------
#    Left wrist   (0.99, 0.11)       (0.95, -0.17)      0.283    ✅
#    Right wrist  (0.80, 0.55)       (1.48, 0.09)       0.818    ✅
#    Left elbow   (1.37, -0.06)      (0.89, -0.35)      0.566    ✅
#    Right elbow  (1.08, 0.58)       (1.12, 0.27)       0.309    ✅
#    Left knee    (-1.20, -0.32)     (-1.21, -0.33)     0.021    ✅
#    Right knee   (-1.37, 0.29)      (-1.01, 0.23)      0.360    ✅
#    ------------------------------------------------------------
#    Average difference: 0.393 ✅ EXCELLENT MATCH!
#  Step 17 COMPLETED (Ju Shichi: Right Lunge Punch (2nd Kiai)) - Similarity: 0.829 at 24.11s (held for 0.03s)
#     Pose detected and normalized
#    Step 'Ju Shichi: Right Lunge Punch (2nd Kiai)' processed successfully
#     POSE COMPARISON for 'Ju Shichi: Right Lunge Punch (2nd Kiai)':
#    ============================================================
#    Joint        User Pose          Reference          Difference
#    ------------------------------------------------------------
#    Left wrist   (0.92, 0.23)       (0.95, -0.17)      0.404    ✅
#    Right wrist  (0.74, 0.50)       (1.48, 0.09)       0.842    ✅
#    Left elbow   (1.31, 0.03)       (0.89, -0.35)      0.577    ✅
#    Right elbow  (1.16, 0.42)       (1.12, 0.27)       0.149    ✅
#    Left knee    (-1.17, -0.33)     (-1.21, -0.33)     0.036    ✅
#    Right knee   (-1.34, 0.29)      (-1.01, 0.23)      0.338    ✅
#    ------------------------------------------------------------
#    Average difference: 0.391 ✅ EXCELLENT MATCH!
# --------------------------------------------------------------------------------
#    🔍 HYBRID DEBUG: COS=-0.205, DIST_SIM=0.000, AVG_DIST=9.88, PENALTY=0.100, FINAL=-0.012
#    🔍 HYBRID DEBUG: COS=-0.253, DIST_SIM=0.000, AVG_DIST=7.43, PENALTY=0.100, FINAL=-0.015
#    🔍 HYBRID DEBUG: COS=-0.221, DIST_SIM=0.000, AVG_DIST=7.23, PENALTY=0.100, FINAL=-0.013
#    🔍 HYBRID DEBUG: COS=-0.220, DIST_SIM=0.000, AVG_DIST=7.41, PENALTY=0.100, FINAL=-0.013
#    🔍 HYBRID DEBUG: COS=-0.222, DIST_SIM=0.000, AVG_DIST=7.89, PENALTY=0.100, FINAL=-0.013
#    🔍 HYBRID DEBUG: COS=-0.213, DIST_SIM=0.000, AVG_DIST=8.88, PENALTY=0.100, FINAL=-0.013
#    🔍 HYBRID DEBUG: COS=-0.247, DIST_SIM=0.000, AVG_DIST=9.22, PENALTY=0.100, FINAL=-0.015
#    🔍 HYBRID DEBUG: COS=-0.263, DIST_SIM=0.000, AVG_DIST=9.72, PENALTY=0.100, FINAL=-0.016
#    🔍 HYBRID DEBUG: COS=-0.260, DIST_SIM=0.000, AVG_DIST=10.31, PENALTY=0.100, FINAL=-0.016
#    🔍 HYBRID DEBUG: COS=-0.020, DIST_SIM=0.000, AVG_DIST=12.24, PENALTY=0.100, FINAL=-0.001
#    🔍 HYBRID DEBUG: COS=-0.002, DIST_SIM=0.000, AVG_DIST=8.07, PENALTY=0.100, FINAL=-0.000
#    🔍 HYBRID DEBUG: COS=-0.004, DIST_SIM=0.000, AVG_DIST=6.12, PENALTY=0.100, FINAL=-0.000
#    🔍 HYBRID DEBUG: COS=0.004, DIST_SIM=0.000, AVG_DIST=4.56, PENALTY=0.479, FINAL=0.001
#    🔍 HYBRID DEBUG: COS=0.483, DIST_SIM=0.000, AVG_DIST=4.75, PENALTY=0.417, FINAL=0.121
#    🔍 HYBRID DEBUG: COS=0.567, DIST_SIM=0.000, AVG_DIST=4.96, PENALTY=0.348, FINAL=0.119
#    🔍 HYBRID DEBUG: COS=0.607, DIST_SIM=0.000, AVG_DIST=5.18, PENALTY=0.273, FINAL=0.099
#    🔍 HYBRID DEBUG: COS=0.621, DIST_SIM=0.000, AVG_DIST=6.55, PENALTY=0.100, FINAL=0.037
#    🔍 HYBRID DEBUG: COS=0.619, DIST_SIM=0.000, AVG_DIST=7.56, PENALTY=0.100, FINAL=0.037
#    🔍 HYBRID DEBUG: COS=0.667, DIST_SIM=0.000, AVG_DIST=7.92, PENALTY=0.100, FINAL=0.040
#    🔍 HYBRID DEBUG: COS=0.684, DIST_SIM=0.000, AVG_DIST=10.19, PENALTY=0.100, FINAL=0.041
#    🔍 HYBRID DEBUG: COS=0.588, DIST_SIM=0.000, AVG_DIST=12.02, PENALTY=0.100, FINAL=0.035
#    🔍 HYBRID DEBUG: COS=0.754, DIST_SIM=0.000, AVG_DIST=12.25, PENALTY=0.100, FINAL=0.045
#    🔍 HYBRID DEBUG: COS=0.777, DIST_SIM=0.000, AVG_DIST=9.51, PENALTY=0.100, FINAL=0.047
#    🔍 HYBRID DEBUG: COS=0.855, DIST_SIM=0.000, AVG_DIST=12.07, PENALTY=0.100, FINAL=0.051
#    🔍 HYBRID DEBUG: COS=0.870, DIST_SIM=0.000, AVG_DIST=12.34, PENALTY=0.100, FINAL=0.052
#  MATCH STARTED at frame 1001 (26.26s)! Step: 18, Similarity: 0.8778
#     Pose detected and normalized
#    Step 'Ju Hachi: Left Knife Hand Block' match detected
#     POSE COMPARISON for 'Ju Hachi: Left Knife Hand Block':
#    ============================================================
#    Joint        User Pose          Reference          Difference
#    ------------------------------------------------------------
#    Left wrist   (2.25, 0.64)       (1.57, 0.81)       0.704    ✅
#    Right wrist  (1.31, 0.02)       (1.08, 0.21)       0.297    ✅
#    Left elbow   (2.08, 0.55)       (1.35, 0.42)       0.746    ✅
#    Right elbow  (1.23, -0.37)      (0.82, -0.23)      0.438    ✅
#    Left knee    (-1.05, 0.62)      (-1.06, 0.59)      0.031    ✅
#    Right knee   (-1.32, -0.33)     (-1.45, -0.28)     0.140    ✅
#    ------------------------------------------------------------
#    Average difference: 0.393 ✅ EXCELLENT MATCH!
#  Step 18 COMPLETED (Ju Hachi: Left Knife Hand Block) - Similarity: 0.900 at 26.28s (held for 0.03s)
#     Pose detected and normalized
#    Step 'Ju Hachi: Left Knife Hand Block' processed successfully
#     POSE COMPARISON for 'Ju Hachi: Left Knife Hand Block':
#    ============================================================
#    Joint        User Pose          Reference          Difference
#    ------------------------------------------------------------
#    Left wrist   (2.01, 0.96)       (1.57, 0.81)       0.466    ✅
#    Right wrist  (1.21, 0.07)       (1.08, 0.21)       0.201    ✅
#    Left elbow   (1.87, 0.64)       (1.35, 0.42)       0.566    ✅
#    Right elbow  (1.11, -0.37)      (0.82, -0.23)      0.327    ✅
#    Left knee    (-1.06, 0.59)      (-1.06, 0.59)      0.002    ✅
#    Right knee   (-1.36, -0.29)     (-1.45, -0.28)     0.090    ✅
#    ------------------------------------------------------------
#    Average difference: 0.275 ✅ EXCELLENT MATCH!
# --------------------------------------------------------------------------------
#
# ==================================================
#  Video processing completed with FIXED TIME PERCEPTION and KEY POINTS PREVIEW.
#  18 steps succeeded / 18 total.
#  CSV saved: match_stats_simple.csv
#  Video saved: output_detected_simple.mp4
#
#  SUMMARY:
#    Successful steps: 18
#    Timeout steps: 0
#    Success rate: 100.0%
#    Average similarity (successful): 0.719
#    Similarity range (successful): 0.554 - 0.944
#    • Combines cosine similarity (angles) + distance constraints (positions)
#    • Prevents false positives from similar angles but different positions
#    • Configurable distance threshold and weight parameters
#    • Distance penalty system for poses that are too far apart
#    • Enhanced pose comparison showing user vs reference coordinates
#    • Side-by-side analysis with difference calculations
#    • Color-coded match quality indicators (✅⚠️❌)
#    • Euclidean distance measurements for each joint
#    • Average difference scoring with match quality assessment
#  Robust pose matching system with hybrid similarity implemented!
